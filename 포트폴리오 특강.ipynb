# %% [markdown]
# IT포트폴리오 작성 실무 특강
#
# 오창희 강사님(och8808@gmail.com)
# 1. 개발자
# 2. 학습
# 3. 정보
# 4. 깃허브
# 5. QnA
#
# 개인적으로 -미래와 경쟁하라 라는 문구가 좋은듯
# 강사는 '문제해결력'이라는 것이 중요하다고 함. 근데 이를 보여주는 방식이 코딩임.
#
# 포트폴리오란 나의 이력을 보여주는 것임.
#
# 아래의 주소에서 ppt를 설명함(개발자의 학과 습. 구글검색시 찾을 수 있음)
# https://www.youtube.com/watch?v=qlNzmQEuMjQ&t=1s
# 학과 습이 중요함.
# 배울 학, 익힐 습
# 학 - 목표
# 목표: 근의 공식 이해
# 이유: 근의 공식으로 해를 구하기 위해
# 문제: 해를 구하는데 오래 걸리는데? 빠르게 해결할 방법이 필요해!
#
# 카테고리 기반 vs 문제 기반
#
# 빠르게 학습할 수 없는가?
#
# 학 - 매핑
# - 기존의 배경 지식과 연결하기
#
# 매핑, 기존의 배경 지식과 연결지어 새로운 것을 빠르게 배울 수 있다.
#
# 같이 하는 커뮤니케이션
#
# 정보(취업 준비는 어떻게??)
# - 카톡, 개발자 뉴스레터, 블로그, 로켓펀치(채용사이트)
#
# required Skills 이런 항목에서
# react.js node.js 등을 다뤄본 사람이면 좋겠다고 한다면,
# 이것들을 다뤄봤으며 이것들에 대한 이해가 있으면 여기서 배우면 된다고 인지하는 것임.
#
# 네카라쿠배당토
# 네이버, 카카오, 라인, 쿠팡, 배민, 당근, 토스
#
# 각 기업의 컨퍼런스를 보면 그 회사에서 무엇에 관심을 가지는지 알 수 있음
#
# 각 스택이나 직군을 원할 때 무엇을 배워야할지 잘 모르겠을 때 참고할 사이트
# https://roadmap.sh/
#
#
# 노션을 통한 이력서 및 자소서
#
# 노션 이력서 탬플릿을 사용하면 됨.
# 그리고 자소서같은 경우는 다른 분들이 어떻게 작성했는지 참고
#
#
# 코테같은 경우 수능과 같은 경우라고 볼 수 있음.
# 수능은 대학수학능력평가 인데 수학이 math가 아닌 배울 준비가 됐는지에 대한 평가를 하는 것임.
# 이에 따라 각 분야별로 다른 평가가 필요하지만 이가 복잡하므로 종합적으로 수능이라는 것을 이용하게 되는 것임.
#
# 코테는
# 프로그래머스, 백준, sw expert academy 주로 3가지 방법으로 연습할 수 있음
#
# 프로그래머스 기준으로 기초 단계에서 정답율 80프로 중반까지는 틀려서는 안되는 것임.
#
# 알고리즘은 어디서 등장하느냐가 중요한데 이는 기출문제에서 주로 나옴
#
# 카카오 코테의 경우에는 7문제중 4문제가 합격선이었다고 함.(문제는 easy -> hard순)
# 1번은 일반적인 형변환 문제
# 2번 그리디 전략?? 알고리즘중 일부인듯
# 효율적인 방법으로 풀이하는 것을 코드로 구현하는 것(구현문제임) = '탐욕법'이라고 하는듯
# 3번 기본 문제?인듯(여기까지 알고리즘이 필요없음)
# 4번부터는 알고리즘이 뭔지 알아야 수월하거나 맞출 수 있음.
#
# <h3> 프로그래머스 고득점 Kit </h3>
# 이와같은 코딩테스트 항목에 고득점Kit(프로그래머스 기준)을 들어가서 공부하면 됨
# 해시, 스택/큐, 힙까지는 일반적인 코딩에 가까움
# 정렬, 완전탐색, 탐욕법, 동적계획법, DFS/BFS, 이분탐색, 그래프 까지!! 보통 배우는 내용이며 알고리즘이라고 부를 수 있는 내용임(대학 학부생 기준임. 그러다 보니 이 범위 밖으로 안나감.)
#
# 어려운 것은 DP, DFS/BFS, 이분탐색, 그래프까지... 이후의 내용은 어렵긴 한데 잘 모르겠는 것들
#
# 백준에서는 분류항목 기준 '다익스크라'까지 나온다고 보면 된다고 하심;
#
# 추가로 코테는 만점이 목표가 아니라 현실적으로 4~5문제를 푸는 것이 목표라고 생각하면 된다고 함
