# %%
# matplotlib
# 분석 개요: 9시~9시20분
# 분석: 9시20분~오후4시50분
# 점심: 11시50분 ~ 오후 1시
# 발표: 5시~5시40분(인당 약 5분)

# 타이타닉, 
# 미국 태생 아이들 이름 분석(120년), 
# 의료데이터(사이트), 
# 자전거 대여 데이터, 
# 사회복지 데이터
# 졸음운전 교통사고 분석

# data.go.kr
# aihub.or.kr
# kaggle.com
# dacon.io
# 통계청 등 각 공공기관 open api

# %%
# 한글깨짐 현상 방지 코드
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
# https://matplotlib.org/2.0.2/gallery.html
# https://matplotlib.org/2.0.2/examples/color/named_colors.html 색깔(color) 참고
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,3))
plt.title("Plot")
# plt.figure(figsize=(6,6))
plt.plot([1, 4, 9, 16])
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 라벨")
plt.ylabel("와이축 라벨")
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title("'rs--' 스타일의 plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.show()

# %%
# https://matplotlib.org/2.0.2/api/lines_api.html#matplotlib.lines.Line2D
# plot의 설명은 위 주소 참고
plt.figure(figsize=(5,3))
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
plt.plot([1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
# c는 컬러,lw는 부동소수점, ls는 선종류, marker는 마커종류, mec는 모든 matplotlib의 색상,
#  ms는 마커크기, mew는 부동소수점값 mfc는 마커표면색상
# plt.hold(True)   # <- 1,5 버전에서는 이 코드가 필요하다.
plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")
# plt.hold(False)  # <- 1,5 버전에서는 이 코드가 필요하다.
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2)) # 여기서는 쓰이지 않았다고 하시는데 실제로 크기는 적용된듯?
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
subplot(2, 1, 1)
# 여기에서 윗부분에 그릴 플롯 명령 실행
subplot(2, 1, 2)
# 여기에서 아랫부분에 그릴 플롯 명령 실행

# %%
subplot(1,2,1)

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout() # 구분하는 역할로 사용함
plt.show()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

y = [2, 3, 1]
x = np.arange(len(y))
xlabel = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(y_pos, performance, xerr=error, alpha=0.4)
plt.yticks(y_pos, people)
plt.xlabel('x 라벨')
plt.show()

# %%
# 상관관계를 표현할 때 사용하기 좋음
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title("Stem Plot")
plt.stem(x, np.cos(x), '-.')
plt.show()

# %%
# 파이차트
plt.figure(figsize=(7,7))
labels = ['개구리', '돼지', '개', '통나무']
sizes = [15, 30, 45, 10] # 백분율
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0) # 돌출
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins=10) # 10개의 구간으로 나눠서 보여줌
# 위 변수는 제거해도 동일한 결과를 보여줌. 즉 따로 사용할 필요가 있을 때 사용하는 것.
plt.show()

# %%
arrays # 구간별 빈도수 출력
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins # 구간
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %%
np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot") # 산점도
plt.scatter(X, Y)
plt.show() # 그림은 현재 2차원으로 그림이 그려짐

# %%
# 담주부터는 통계를 기초부터 시작할 것임
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show() # 2차원 평면에 4차원 데이터를 추상화하면 표현한 것임

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[3]
print(X)

################################################ 위는 숫자를 리스트로 아래는 그림으로
plt.title("mnist digits; 0")
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()
# Out:
# [[ 0.  0.  7. 15. 13.  1.  0.  0.]
#  [ 0.  8. 13.  6. 15.  4.  0.  0.]
#  [ 0.  2.  1. 13. 13.  0.  0.  0.]
#  [ 0.  0.  2. 15. 11.  1.  0.  0.]
#  [ 0.  0.  0.  1. 12. 12.  1.  0.]
#  [ 0.  0.  0.  0.  1. 10.  8.  0.]
#  [ 0.  0.  8.  4.  5. 14.  9.  0.]
#  [ 0.  0.  7. 13. 13.  9.  0.  0.]]

# %%
import seaborn as sns
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터
tips = sns.load_dataset("tips")    # 팁 데이터
flights = sns.load_dataset("flights")    # 여객운송 데이터

# %%
x = iris.petal_length.values
sns.rugplot(x)
plt.title('Iris 데이터 중, 꽃잎의 길이에 대한 Rug Plot') # 데이터의 분포를 나타낼때 쓰임.
plt.show()
# 어느선이 굵은지 보고 어디에 많이 분포했는지 판단 가능한데... 여기는 너무 얇음.
# 아래에서 더 자세히 나옴
sns.kdeplot(x)
plt.title("Iris 데이터 중, 꽃잎의 길이에 대한 Kernel Density Plot")
plt.show()

# %%
sns.distplot(x, kde=True, rug=True)
plt.title("Iris 데이터 중, 꽃잎의 길이에 대한 Dist Plot")
plt.show()

# %%
sns.countplot(x="class", data=titanic)
plt.title("타이타닉호의 각 클래스별, 승객 수")
plt.show()

# %%
sns.countplot(x="day", data=tips)
plt.title("요일별 팁을 준 횟수")
plt.show()

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris)
plt.suptitle("꽃받침의 길이와 넓이의 Joint Plot", y=1.02)
plt.show()

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris, kind="kde")
plt.suptitle("꽃받침의 길이와 넓이의 Joint Plot 과 Kernel Density Plot", y=1.02)
plt.show()

# %%
sns.pairplot(iris)
plt.title("Iris Data의 Pair Plot")
plt.show()

# %%
sns.pairplot(iris, hue="species", markers=["o", "s", "D"]) 
# hue 옵션이 중요한데 hue에 따라서 구분해서 출력하도록 만들 수 있음
plt.title("Iris Pair Plot, Hue로 꽃의 종을 시각화")
plt.show()

# %%
titanic_size = titanic.pivot_table(
    index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size, cmap=sns.light_palette( # 히트맵 = 열지도 - 분포가 어느정도로 많이, 밀도가 높은지 볼 때 씀
    "gray", as_cmap=True), annot=True, fmt="d")
plt.title("Heatmap")
plt.show()

# %%
flights_passengers = flights.pivot(index="month", columns="year", values="passengers")
plt.title("연도, 월 별 승객수에 대한 Heatmap")
sns.heatmap(flights_passengers, annot=True, fmt="d", linewidths=1)
plt.show()

# %%
# https://seaborn.pydata.org/examples/index.html
# 위의 공식문서를 확인하여 다양한 분포를 표현할 수 있음
# plotly, tableau를 잘 쓰면 시각화를 잘 하는 것으로 인지하게 됨
# 분석 방법을 알아야함. 분석 과정은 금방 알 수 있음
# 내용의 의미를 더 알아야 함.(그래야 데이터분석이긴 한데;)
# 데이터사이언스는 많아야 A4용지 몇장안됨. 다른 분야는 몇백페이지...
