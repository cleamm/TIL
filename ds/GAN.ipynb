# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
import numpy as np
import matplotlib.pyplot as plt

# %%
# 생성자 모델
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D()) # 이미지 확대 역할
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %%
# 판별자 모델
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %%
# 생성자와 판별자 모델을 연결시키는 gan 모델
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
# 신경망을 실행시키는 함수
def gan_train(epoch, batch_size, saving_interval):
  # MNIST 데이터를 불러옵니다.
  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분
        #이미지들은 gan_images 폴더에 저장
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              # 아래 코드는 폴더를 data/gan_images 폴더를 만들어야함
              fig.savefig("./data/gan_images/gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장
# Out:
# epoch:0  d_loss:0.4994  g_loss:0.2334
# epoch:1  d_loss:0.4882  g_loss:0.0812
# epoch:2  d_loss:0.5323  g_loss:0.0527
# epoch:3  d_loss:0.5200  g_loss:0.0847
# epoch:4  d_loss:0.4876  g_loss:0.1899
# epoch:5  d_loss:0.4570  g_loss:0.3764
# epoch:6  d_loss:0.4540  g_loss:0.5248
# epoch:7  d_loss:0.4460  g_loss:0.6037
# epoch:8  d_loss:0.4316  g_loss:0.6637
# epoch:9  d_loss:0.4548  g_loss:0.6427
# epoch:10  d_loss:0.4454  g_loss:0.6509
# epoch:11  d_loss:0.5071  g_loss:0.5626
# epoch:12  d_loss:0.5523  g_loss:0.5209
# epoch:13  d_loss:0.5090  g_loss:0.5735
# epoch:14  d_loss:0.4188  g_loss:0.5343
# epoch:15  d_loss:0.3810  g_loss:0.3479
# epoch:16  d_loss:0.3297  g_loss:0.1918
# epoch:17  d_loss:0.2469  g_loss:0.1247
# epoch:18  d_loss:0.2004  g_loss:0.1600
# epoch:19  d_loss:0.1737  g_loss:0.2860
# epoch:20  d_loss:0.2054  g_loss:0.1713
# epoch:21  d_loss:0.2571  g_loss:0.1717
# epoch:22  d_loss:0.2530  g_loss:0.5661
# epoch:23  d_loss:0.5759  g_loss:0.1599
# epoch:24  d_loss:0.5359  g_loss:0.4841
# epoch:25  d_loss:0.7517  g_loss:0.5043
# epoch:26  d_loss:0.8135  g_loss:0.3160
# epoch:27  d_loss:0.9241  g_loss:0.4335
# epoch:28  d_loss:0.8094  g_loss:0.4142
# epoch:29  d_loss:0.7108  g_loss:0.4944
# epoch:30  d_loss:0.4405  g_loss:0.7360
# epoch:31  d_loss:0.3174  g_loss:0.9566
# epoch:32  d_loss:0.2132  g_loss:0.9243
# epoch:33  d_loss:0.1623  g_loss:1.0983
# epoch:34  d_loss:0.1532  g_loss:1.4207
# epoch:35  d_loss:0.2642  g_loss:1.8689
# epoch:36  d_loss:0.1704  g_loss:2.4688
# epoch:37  d_loss:0.4109  g_loss:3.4039
# epoch:38  d_loss:0.7179  g_loss:2.3889
# epoch:39  d_loss:0.7867  g_loss:2.2059
# epoch:40  d_loss:0.7749  g_loss:2.2156
# epoch:41  d_loss:0.8541  g_loss:1.8885
# epoch:42  d_loss:0.6809  g_loss:1.5525
# epoch:43  d_loss:0.6309  g_loss:1.6523
# epoch:44  d_loss:0.7175  g_loss:1.2734
# epoch:45  d_loss:0.6483  g_loss:1.3530
# epoch:46  d_loss:0.5334  g_loss:1.1453
# epoch:47  d_loss:0.5231  g_loss:0.8540
# epoch:48  d_loss:0.4930  g_loss:0.8587
# epoch:49  d_loss:0.4632  g_loss:1.0860
# epoch:50  d_loss:0.3194  g_loss:1.1511
# epoch:51  d_loss:0.3601  g_loss:1.2470
# epoch:52  d_loss:0.3829  g_loss:1.1100
# epoch:53  d_loss:0.3962  g_loss:1.1205
# epoch:54  d_loss:0.2946  g_loss:1.3412
# epoch:55  d_loss:0.2871  g_loss:1.1486
# epoch:56  d_loss:0.2610  g_loss:1.3434
# epoch:57  d_loss:0.2764  g_loss:1.1544
# epoch:58  d_loss:0.2830  g_loss:1.1175
# epoch:59  d_loss:0.2616  g_loss:1.1621
# epoch:60  d_loss:0.2606  g_loss:1.0660
# epoch:61  d_loss:0.1763  g_loss:1.5641
# epoch:62  d_loss:0.2550  g_loss:1.6812
# epoch:63  d_loss:0.2651  g_loss:1.3050
# epoch:64  d_loss:0.3801  g_loss:0.7091
# epoch:65  d_loss:0.3709  g_loss:0.7909
# epoch:66  d_loss:0.3653  g_loss:0.8895
# epoch:67  d_loss:0.2291  g_loss:1.6637
# epoch:68  d_loss:0.2690  g_loss:1.8949
# epoch:69  d_loss:0.4652  g_loss:1.2325
# epoch:70  d_loss:0.3575  g_loss:0.9419
# epoch:71  d_loss:0.3983  g_loss:0.8489
# epoch:72  d_loss:0.4637  g_loss:1.0376
# epoch:73  d_loss:0.4743  g_loss:1.4147
# epoch:74  d_loss:0.8032  g_loss:0.9853
# epoch:75  d_loss:1.0390  g_loss:0.5402
# epoch:76  d_loss:0.9939  g_loss:0.5945
# epoch:77  d_loss:0.5315  g_loss:0.8594
# epoch:78  d_loss:0.3932  g_loss:1.0773
# epoch:79  d_loss:0.2254  g_loss:1.3853
# epoch:80  d_loss:0.1940  g_loss:1.4631
# epoch:81  d_loss:0.1668  g_loss:1.5904
# epoch:82  d_loss:0.1286  g_loss:1.4253
# epoch:83  d_loss:0.0938  g_loss:1.4222
# epoch:84  d_loss:0.0837  g_loss:1.3381
# epoch:85  d_loss:0.1094  g_loss:1.2763
# epoch:86  d_loss:0.2064  g_loss:1.4935
# epoch:87  d_loss:0.1583  g_loss:1.6563
# epoch:88  d_loss:0.1562  g_loss:1.5315
# epoch:89  d_loss:0.2774  g_loss:1.7410
# epoch:90  d_loss:0.1987  g_loss:2.2297
# epoch:91  d_loss:0.2872  g_loss:2.8742
# epoch:92  d_loss:0.5111  g_loss:2.0994
# epoch:93  d_loss:0.5228  g_loss:1.5417
# epoch:94  d_loss:0.5373  g_loss:1.7238
# epoch:95  d_loss:0.5397  g_loss:1.5309
# epoch:96  d_loss:0.7404  g_loss:1.7855
# epoch:97  d_loss:0.4522  g_loss:2.2021
# epoch:98  d_loss:0.8221  g_loss:1.5995
# epoch:99  d_loss:0.7022  g_loss:1.9899
# epoch:100  d_loss:1.1312  g_loss:1.0734
# epoch:101  d_loss:0.9408  g_loss:1.3875
# epoch:102  d_loss:0.7715  g_loss:1.4976
# epoch:103  d_loss:0.8356  g_loss:1.8480
# epoch:104  d_loss:0.8188  g_loss:1.9677
# epoch:105  d_loss:0.8304  g_loss:1.6876
# epoch:106  d_loss:0.6801  g_loss:1.6370
# epoch:107  d_loss:0.6601  g_loss:1.5055
# epoch:108  d_loss:0.6549  g_loss:1.6163
# epoch:109  d_loss:0.5815  g_loss:1.9860
# epoch:110  d_loss:0.5821  g_loss:1.8862
# epoch:111  d_loss:0.5114  g_loss:2.0481
# epoch:112  d_loss:0.6860  g_loss:1.6036
# epoch:113  d_loss:0.5220  g_loss:1.8100
# epoch:114  d_loss:0.5316  g_loss:1.6227
# epoch:115  d_loss:0.4631  g_loss:1.8607
# epoch:116  d_loss:0.4429  g_loss:2.0052
# epoch:117  d_loss:0.5473  g_loss:1.9157
# epoch:118  d_loss:0.5054  g_loss:1.6069
# epoch:119  d_loss:0.4413  g_loss:1.7394
# epoch:120  d_loss:0.5450  g_loss:1.3839
# epoch:121  d_loss:0.4258  g_loss:1.7123
# epoch:122  d_loss:0.4292  g_loss:1.7569
# epoch:123  d_loss:0.5186  g_loss:1.5701
# epoch:124  d_loss:0.4681  g_loss:1.3659
# epoch:125  d_loss:0.4167  g_loss:1.4964
# epoch:126  d_loss:0.5553  g_loss:1.3084
# epoch:127  d_loss:0.4442  g_loss:1.2295
# epoch:128  d_loss:0.5513  g_loss:1.4601
# epoch:129  d_loss:0.5339  g_loss:1.1055
# epoch:130  d_loss:0.5304  g_loss:1.0334
# epoch:131  d_loss:0.5652  g_loss:0.8234
# epoch:132  d_loss:0.5248  g_loss:1.0756
# epoch:133  d_loss:0.6320  g_loss:1.0229
# epoch:134  d_loss:0.5985  g_loss:1.1608
# epoch:135  d_loss:0.6785  g_loss:1.1115
# epoch:136  d_loss:0.6407  g_loss:0.9927
# epoch:137  d_loss:0.6637  g_loss:0.9046
# epoch:138  d_loss:0.6319  g_loss:0.9123
# epoch:139  d_loss:0.5391  g_loss:0.8479
# epoch:140  d_loss:0.6894  g_loss:0.8373
# epoch:141  d_loss:0.5707  g_loss:0.9148
# epoch:142  d_loss:0.5891  g_loss:1.0452
# epoch:143  d_loss:0.6265  g_loss:1.0501
# epoch:144  d_loss:0.5104  g_loss:1.4350
# epoch:145  d_loss:0.5695  g_loss:1.3281
# epoch:146  d_loss:0.4710  g_loss:1.2587
# epoch:147  d_loss:0.4674  g_loss:1.4000
# epoch:148  d_loss:0.5604  g_loss:1.4028
# epoch:149  d_loss:0.5164  g_loss:1.7435
# epoch:150  d_loss:0.5075  g_loss:1.5135
# epoch:151  d_loss:0.4753  g_loss:1.7077
# epoch:152  d_loss:0.5605  g_loss:1.7781
# epoch:153  d_loss:0.6065  g_loss:1.7505
# epoch:154  d_loss:0.7016  g_loss:1.4641
# epoch:155  d_loss:0.6404  g_loss:1.1912
# epoch:156  d_loss:0.7381  g_loss:1.4409
# epoch:157  d_loss:0.9523  g_loss:1.5288
# epoch:158  d_loss:0.6543  g_loss:1.4978
# epoch:159  d_loss:0.6814  g_loss:1.6900
# epoch:160  d_loss:0.6513  g_loss:1.4678
# epoch:161  d_loss:0.7673  g_loss:1.4102
# epoch:162  d_loss:0.6921  g_loss:1.2061
# epoch:163  d_loss:0.5681  g_loss:1.3133
# epoch:164  d_loss:0.5817  g_loss:1.3110
# epoch:165  d_loss:0.4636  g_loss:1.3055
# epoch:166  d_loss:0.4120  g_loss:1.4608
# epoch:167  d_loss:0.4109  g_loss:1.7013
# epoch:168  d_loss:0.4684  g_loss:1.8949
# epoch:169  d_loss:0.4266  g_loss:1.7612
# epoch:170  d_loss:0.4135  g_loss:1.3160
# epoch:171  d_loss:0.4000  g_loss:1.4215
# epoch:172  d_loss:0.3881  g_loss:1.2465
# epoch:173  d_loss:0.3842  g_loss:1.4701
# epoch:174  d_loss:0.4676  g_loss:1.5201
# epoch:175  d_loss:0.2857  g_loss:2.0391
# epoch:176  d_loss:0.4097  g_loss:1.7270
# epoch:177  d_loss:0.3053  g_loss:1.7524
# epoch:178  d_loss:0.3708  g_loss:1.7251
# epoch:179  d_loss:0.3661  g_loss:1.8098
# epoch:180  d_loss:0.3623  g_loss:1.7090
# epoch:181  d_loss:0.4802  g_loss:1.5501
# epoch:182  d_loss:0.4081  g_loss:1.6680
# epoch:183  d_loss:0.4521  g_loss:1.8837
# epoch:184  d_loss:0.3432  g_loss:1.7560
# epoch:185  d_loss:0.5847  g_loss:1.7825
# epoch:186  d_loss:0.5826  g_loss:1.6353
# epoch:187  d_loss:0.5676  g_loss:1.5005
# epoch:188  d_loss:0.5287  g_loss:1.7152
# epoch:189  d_loss:0.8258  g_loss:1.0111
# epoch:190  d_loss:0.7444  g_loss:0.9920
# epoch:191  d_loss:0.6932  g_loss:1.2893
# epoch:192  d_loss:0.5420  g_loss:1.6884
# epoch:193  d_loss:0.7537  g_loss:1.7102
# epoch:194  d_loss:0.8177  g_loss:1.4724
# epoch:195  d_loss:0.5114  g_loss:1.3357
# epoch:196  d_loss:0.4157  g_loss:1.4111
# epoch:197  d_loss:0.3984  g_loss:1.4892
# epoch:198  d_loss:0.2050  g_loss:2.1780
# epoch:199  d_loss:0.2214  g_loss:2.1591
# epoch:200  d_loss:0.1102  g_loss:2.8004
# epoch:201  d_loss:0.1038  g_loss:3.4276
# epoch:202  d_loss:0.1428  g_loss:3.3012
# epoch:203  d_loss:0.1246  g_loss:3.6063
# epoch:204  d_loss:0.0792  g_loss:2.9644
# epoch:205  d_loss:0.1524  g_loss:2.3119
# epoch:206  d_loss:0.2298  g_loss:2.1458
# epoch:207  d_loss:0.2456  g_loss:2.1633
# epoch:208  d_loss:0.3392  g_loss:2.2829
# epoch:209  d_loss:0.2322  g_loss:3.4009
# epoch:210  d_loss:0.2390  g_loss:4.3023
# epoch:211  d_loss:0.7553  g_loss:3.5084
# epoch:212  d_loss:0.7523  g_loss:2.3826
# epoch:213  d_loss:0.6642  g_loss:1.8744
# epoch:214  d_loss:0.8662  g_loss:1.6490
# epoch:215  d_loss:0.6611  g_loss:1.5116
# epoch:216  d_loss:0.7933  g_loss:2.1143
# epoch:217  d_loss:0.5883  g_loss:2.5813
# epoch:218  d_loss:0.4630  g_loss:3.4379
# epoch:219  d_loss:0.6088  g_loss:3.3982
# epoch:220  d_loss:0.6815  g_loss:2.7963
# epoch:221  d_loss:0.3711  g_loss:2.9253
# epoch:222  d_loss:0.5201  g_loss:2.8200
# epoch:223  d_loss:0.4217  g_loss:2.7578
# epoch:224  d_loss:0.2554  g_loss:2.8988
# epoch:225  d_loss:0.3256  g_loss:2.8600
# epoch:226  d_loss:0.3338  g_loss:3.0362
# epoch:227  d_loss:0.3120  g_loss:3.1183
# epoch:228  d_loss:0.3002  g_loss:3.4321
# epoch:229  d_loss:0.3169  g_loss:3.0724
# epoch:230  d_loss:0.3281  g_loss:3.0325
# epoch:231  d_loss:0.3289  g_loss:2.6988
# epoch:232  d_loss:0.3327  g_loss:3.2283
# epoch:233  d_loss:0.3872  g_loss:2.3870
# epoch:234  d_loss:0.3915  g_loss:2.5661
# epoch:235  d_loss:0.4938  g_loss:2.3684
# epoch:236  d_loss:0.3510  g_loss:2.4685
# epoch:237  d_loss:0.4595  g_loss:2.3673
# epoch:238  d_loss:0.2336  g_loss:2.8106
# epoch:239  d_loss:0.3176  g_loss:2.3634
# epoch:240  d_loss:0.3518  g_loss:2.4693
# epoch:241  d_loss:0.4188  g_loss:2.4217
# epoch:242  d_loss:0.3348  g_loss:2.2594
# epoch:243  d_loss:0.4004  g_loss:2.1986
# epoch:244  d_loss:0.4094  g_loss:2.2345
# epoch:245  d_loss:0.5456  g_loss:1.9584
# epoch:246  d_loss:0.4428  g_loss:1.9645
# epoch:247  d_loss:0.4699  g_loss:2.2113
# epoch:248  d_loss:0.5131  g_loss:1.3996
# epoch:249  d_loss:0.5153  g_loss:1.6032
# epoch:250  d_loss:0.4134  g_loss:2.0259
# epoch:251  d_loss:0.4173  g_loss:2.0183
# epoch:252  d_loss:0.7135  g_loss:1.7101
# epoch:253  d_loss:0.6835  g_loss:1.4835
# epoch:254  d_loss:0.6593  g_loss:1.4554
# epoch:255  d_loss:0.4916  g_loss:1.3693
# epoch:256  d_loss:0.5351  g_loss:1.4592
# epoch:257  d_loss:0.3966  g_loss:1.5632
# epoch:258  d_loss:0.4716  g_loss:1.7179
# epoch:259  d_loss:0.3896  g_loss:2.0780
# epoch:260  d_loss:0.3597  g_loss:1.8819
# epoch:261  d_loss:0.3263  g_loss:1.6298
# epoch:262  d_loss:0.3430  g_loss:1.9017
# epoch:263  d_loss:0.3925  g_loss:2.1536
# epoch:264  d_loss:0.3929  g_loss:2.0624
# epoch:265  d_loss:0.4279  g_loss:2.1857
# epoch:266  d_loss:0.4117  g_loss:2.0124
# epoch:267  d_loss:0.3866  g_loss:2.0071
# epoch:268  d_loss:0.3627  g_loss:2.1735
# epoch:269  d_loss:0.4194  g_loss:2.1749
# epoch:270  d_loss:0.3727  g_loss:2.5377
# epoch:271  d_loss:0.1836  g_loss:3.2538
# epoch:272  d_loss:0.6411  g_loss:2.6372
# epoch:273  d_loss:0.4602  g_loss:2.3020
# epoch:274  d_loss:0.5232  g_loss:2.2617
# epoch:275  d_loss:0.4256  g_loss:2.1238
# epoch:276  d_loss:0.3243  g_loss:2.0840
# epoch:277  d_loss:0.4478  g_loss:2.0789
# epoch:278  d_loss:0.6390  g_loss:1.6782
# epoch:279  d_loss:0.7382  g_loss:1.7707
# epoch:280  d_loss:0.7416  g_loss:1.5963
# epoch:281  d_loss:0.5545  g_loss:2.0131
# epoch:282  d_loss:0.6956  g_loss:2.0815
# epoch:283  d_loss:0.5702  g_loss:1.8517
# epoch:284  d_loss:0.5396  g_loss:1.9380
# epoch:285  d_loss:0.8326  g_loss:1.4475
# epoch:286  d_loss:0.7189  g_loss:1.1810
# epoch:287  d_loss:0.5977  g_loss:1.3595
# epoch:288  d_loss:0.5310  g_loss:1.3920
# epoch:289  d_loss:0.6652  g_loss:1.3827
# epoch:290  d_loss:0.6600  g_loss:1.3769
# epoch:291  d_loss:0.6639  g_loss:1.5474
# epoch:292  d_loss:0.5572  g_loss:1.6477
# epoch:293  d_loss:0.5488  g_loss:1.5460
# epoch:294  d_loss:0.6208  g_loss:1.2382
# epoch:295  d_loss:0.5756  g_loss:1.3083
# epoch:296  d_loss:0.5362  g_loss:1.1911
# epoch:297  d_loss:0.4905  g_loss:1.4659
# epoch:298  d_loss:0.4498  g_loss:1.4919
# epoch:299  d_loss:0.5144  g_loss:1.3337
# epoch:300  d_loss:0.5318  g_loss:1.4678
# epoch:301  d_loss:0.4838  g_loss:1.5664
# epoch:302  d_loss:0.4682  g_loss:1.5251
# epoch:303  d_loss:0.4038  g_loss:1.8584
# epoch:304  d_loss:0.3566  g_loss:1.7041
# epoch:305  d_loss:0.3739  g_loss:1.8408
# epoch:306  d_loss:0.3879  g_loss:1.8408
# epoch:307  d_loss:0.4127  g_loss:1.8860
# epoch:308  d_loss:0.4412  g_loss:1.8113
# epoch:309  d_loss:0.3462  g_loss:2.0717
# epoch:310  d_loss:0.3515  g_loss:2.0911
# epoch:311  d_loss:0.4107  g_loss:1.8515
# epoch:312  d_loss:0.4136  g_loss:2.0482
# epoch:313  d_loss:0.2857  g_loss:2.2111
# epoch:314  d_loss:0.2767  g_loss:2.2810
# epoch:315  d_loss:0.2994  g_loss:2.1988
# epoch:316  d_loss:0.3096  g_loss:2.1527
# epoch:317  d_loss:0.3054  g_loss:2.0115
# epoch:318  d_loss:0.3164  g_loss:2.2403
# epoch:319  d_loss:0.2867  g_loss:2.2397
# epoch:320  d_loss:0.3542  g_loss:2.3222
# epoch:321  d_loss:0.2243  g_loss:2.7402
# epoch:322  d_loss:0.4185  g_loss:2.6541
# epoch:323  d_loss:0.2719  g_loss:2.7385
# epoch:324  d_loss:0.4175  g_loss:2.3321
# epoch:325  d_loss:0.3696  g_loss:2.3979
# epoch:326  d_loss:0.3293  g_loss:2.1001
# epoch:327  d_loss:0.2676  g_loss:1.8705
# epoch:328  d_loss:0.3454  g_loss:1.7811
# epoch:329  d_loss:0.2959  g_loss:2.6698
# epoch:330  d_loss:0.2695  g_loss:2.1758
# epoch:331  d_loss:0.2296  g_loss:2.0674
# epoch:332  d_loss:0.4666  g_loss:2.4687
# epoch:333  d_loss:0.3721  g_loss:2.1449
# epoch:334  d_loss:0.3045  g_loss:2.7656
# epoch:335  d_loss:0.4947  g_loss:2.3815
# epoch:336  d_loss:0.4195  g_loss:1.9700
# epoch:337  d_loss:0.5573  g_loss:1.6926
# epoch:338  d_loss:0.4749  g_loss:1.6659
# epoch:339  d_loss:0.5194  g_loss:1.4729
# epoch:340  d_loss:0.3767  g_loss:1.6825
# epoch:341  d_loss:0.3889  g_loss:1.9968
# epoch:342  d_loss:0.6437  g_loss:1.9868
# epoch:343  d_loss:0.4298  g_loss:1.5977
# epoch:344  d_loss:0.4787  g_loss:1.5524
# epoch:345  d_loss:0.4782  g_loss:1.7446
# epoch:346  d_loss:0.4398  g_loss:1.8926
# epoch:347  d_loss:0.4933  g_loss:1.6132
# epoch:348  d_loss:0.4412  g_loss:1.7504
# epoch:349  d_loss:0.5034  g_loss:1.8601
# epoch:350  d_loss:0.4206  g_loss:1.4928
# epoch:351  d_loss:0.4385  g_loss:1.5611
# epoch:352  d_loss:0.5338  g_loss:2.1068
# epoch:353  d_loss:0.4424  g_loss:1.6900
# epoch:354  d_loss:0.6805  g_loss:1.3775
# epoch:355  d_loss:0.5667  g_loss:1.1068
# epoch:356  d_loss:0.5088  g_loss:1.3413
# epoch:357  d_loss:0.4196  g_loss:1.8307
# epoch:358  d_loss:0.3832  g_loss:2.0349
# epoch:359  d_loss:0.4494  g_loss:1.9033
# epoch:360  d_loss:0.4600  g_loss:1.7182
# epoch:361  d_loss:0.4674  g_loss:1.7612
# epoch:362  d_loss:0.4792  g_loss:1.5915
# epoch:363  d_loss:0.5842  g_loss:1.4182
# epoch:364  d_loss:0.4674  g_loss:1.4754
# epoch:365  d_loss:0.4506  g_loss:1.9647
# epoch:366  d_loss:0.4517  g_loss:1.6960
# epoch:367  d_loss:0.4112  g_loss:2.1109
# epoch:368  d_loss:0.5324  g_loss:1.6516
# epoch:369  d_loss:0.4170  g_loss:1.8326
# epoch:370  d_loss:0.5109  g_loss:1.6352
# epoch:371  d_loss:0.5096  g_loss:1.7650
# epoch:372  d_loss:0.3893  g_loss:1.8307
# epoch:373  d_loss:0.4320  g_loss:1.5247
# epoch:374  d_loss:0.3845  g_loss:2.3440
# epoch:375  d_loss:0.4100  g_loss:2.1858
# epoch:376  d_loss:0.4732  g_loss:1.9202
# epoch:377  d_loss:0.4130  g_loss:2.2534
# epoch:378  d_loss:0.4707  g_loss:1.7478
# epoch:379  d_loss:0.3226  g_loss:1.7662
# epoch:380  d_loss:0.4783  g_loss:1.6632
# epoch:381  d_loss:0.3532  g_loss:1.7697
# epoch:382  d_loss:0.4636  g_loss:2.0868
# epoch:383  d_loss:0.3402  g_loss:2.5350
# epoch:384  d_loss:0.4179  g_loss:2.2314
# epoch:385  d_loss:0.3826  g_loss:1.9684
# epoch:386  d_loss:0.5072  g_loss:1.7843
# epoch:387  d_loss:0.4678  g_loss:1.7910
# epoch:388  d_loss:0.4558  g_loss:2.0372
# epoch:389  d_loss:0.4229  g_loss:2.0386
# epoch:390  d_loss:0.3810  g_loss:2.0284
# epoch:391  d_loss:0.3030  g_loss:2.2434
# epoch:392  d_loss:0.3747  g_loss:2.2544
# epoch:393  d_loss:0.4224  g_loss:2.2242
# epoch:394  d_loss:0.4243  g_loss:1.9087
# epoch:395  d_loss:0.5421  g_loss:1.5467
# epoch:396  d_loss:0.4253  g_loss:1.6185
# epoch:397  d_loss:0.3573  g_loss:2.0117
# epoch:398  d_loss:0.5248  g_loss:1.9174
# epoch:399  d_loss:0.5520  g_loss:1.7870
# epoch:400  d_loss:0.6921  g_loss:1.8329
# epoch:401  d_loss:0.4113  g_loss:1.8143
# epoch:402  d_loss:0.4912  g_loss:1.5637
# epoch:403  d_loss:0.5149  g_loss:1.8709
# epoch:404  d_loss:0.5417  g_loss:2.0943
# epoch:405  d_loss:0.5171  g_loss:1.7159
# epoch:406  d_loss:0.5762  g_loss:1.9459
# epoch:407  d_loss:0.5136  g_loss:1.8149
# epoch:408  d_loss:0.5563  g_loss:1.8580
# epoch:409  d_loss:0.3788  g_loss:1.9883
# epoch:410  d_loss:0.4498  g_loss:1.9557
# epoch:411  d_loss:0.3441  g_loss:2.1995
# epoch:412  d_loss:0.3738  g_loss:2.2268
# epoch:413  d_loss:0.5682  g_loss:1.8056
# epoch:414  d_loss:0.4397  g_loss:1.6196
# epoch:415  d_loss:0.4175  g_loss:1.5999
# epoch:416  d_loss:0.4909  g_loss:1.9726
# epoch:417  d_loss:0.4016  g_loss:1.9579
# epoch:418  d_loss:0.3767  g_loss:2.2330
# epoch:419  d_loss:0.5241  g_loss:1.7807
# epoch:420  d_loss:0.3550  g_loss:1.7916
# epoch:421  d_loss:0.3659  g_loss:1.7834
# epoch:422  d_loss:0.3655  g_loss:2.0591
# epoch:423  d_loss:0.3040  g_loss:2.2781
# epoch:424  d_loss:0.4591  g_loss:2.0563
# epoch:425  d_loss:0.3555  g_loss:1.9922
# epoch:426  d_loss:0.4073  g_loss:1.8265
# epoch:427  d_loss:0.3386  g_loss:2.6016
# epoch:428  d_loss:0.3364  g_loss:1.9177
# epoch:429  d_loss:0.4100  g_loss:2.4591
# epoch:430  d_loss:0.3338  g_loss:2.2360
# epoch:431  d_loss:0.3827  g_loss:1.9876
# epoch:432  d_loss:0.3157  g_loss:1.8465
# epoch:433  d_loss:0.3272  g_loss:2.0077
# epoch:434  d_loss:0.3757  g_loss:2.0148
# epoch:435  d_loss:0.3909  g_loss:1.9618
# epoch:436  d_loss:0.3364  g_loss:2.0816
# epoch:437  d_loss:0.4103  g_loss:2.0337
# epoch:438  d_loss:0.4677  g_loss:1.6885
# epoch:439  d_loss:0.4051  g_loss:1.8697
# epoch:440  d_loss:0.3804  g_loss:2.4310
# epoch:441  d_loss:0.3027  g_loss:2.3228
# epoch:442  d_loss:0.5045  g_loss:2.0048
# epoch:443  d_loss:0.4942  g_loss:1.5821
# epoch:444  d_loss:0.3770  g_loss:1.9812
# epoch:445  d_loss:0.3837  g_loss:1.9871
# epoch:446  d_loss:0.3965  g_loss:1.9572
# epoch:447  d_loss:0.2978  g_loss:2.2790
# epoch:448  d_loss:0.4477  g_loss:1.8851
# epoch:449  d_loss:0.2478  g_loss:1.5440
# epoch:450  d_loss:0.3664  g_loss:1.7826
# epoch:451  d_loss:0.4475  g_loss:1.6923
# epoch:452  d_loss:0.2622  g_loss:2.3254
# epoch:453  d_loss:0.4553  g_loss:1.8878
# epoch:454  d_loss:0.4597  g_loss:1.4117
# epoch:455  d_loss:0.2828  g_loss:2.1033
# epoch:456  d_loss:0.4151  g_loss:2.2296
# epoch:457  d_loss:0.2729  g_loss:1.9883
# epoch:458  d_loss:0.3946  g_loss:1.4529
# epoch:459  d_loss:0.2718  g_loss:2.1393
# epoch:460  d_loss:0.3570  g_loss:2.0163
# epoch:461  d_loss:0.4167  g_loss:2.4630
# epoch:462  d_loss:0.3845  g_loss:1.9001
# epoch:463  d_loss:0.3511  g_loss:1.8453
# epoch:464  d_loss:0.4186  g_loss:1.6670
# epoch:465  d_loss:0.4522  g_loss:1.7414
# epoch:466  d_loss:0.2822  g_loss:2.3533
# epoch:467  d_loss:0.3711  g_loss:2.0934
# epoch:468  d_loss:0.3109  g_loss:2.2352
# epoch:469  d_loss:0.3129  g_loss:2.5413
# epoch:470  d_loss:0.3133  g_loss:1.7622
# epoch:471  d_loss:0.4228  g_loss:1.5561
# epoch:472  d_loss:0.3532  g_loss:1.8878
# epoch:473  d_loss:0.3789  g_loss:1.8831
# epoch:474  d_loss:0.3127  g_loss:2.3655
# epoch:475  d_loss:0.3958  g_loss:1.8926
# epoch:476  d_loss:0.3528  g_loss:1.9722
# epoch:477  d_loss:0.4263  g_loss:1.6644
# epoch:478  d_loss:0.4687  g_loss:2.0041
# epoch:479  d_loss:0.3840  g_loss:2.0697
# epoch:480  d_loss:0.3558  g_loss:2.1084
# epoch:481  d_loss:0.4118  g_loss:2.1297
# epoch:482  d_loss:0.5100  g_loss:1.7299
# epoch:483  d_loss:0.3055  g_loss:2.1836
# epoch:484  d_loss:0.3965  g_loss:2.0699
# epoch:485  d_loss:0.2491  g_loss:2.3374
# epoch:486  d_loss:0.2691  g_loss:2.5833
# epoch:487  d_loss:0.2375  g_loss:2.6790
# epoch:488  d_loss:0.3567  g_loss:2.1284
# epoch:489  d_loss:0.3364  g_loss:1.8967
# epoch:490  d_loss:0.2668  g_loss:1.9982
# epoch:491  d_loss:0.2540  g_loss:1.9824
# epoch:492  d_loss:0.2097  g_loss:2.5904
# epoch:493  d_loss:0.2157  g_loss:2.6290
# epoch:494  d_loss:0.2386  g_loss:2.5490
# epoch:495  d_loss:0.2117  g_loss:2.5998
# epoch:496  d_loss:0.2199  g_loss:2.6022
# epoch:497  d_loss:0.2127  g_loss:2.0774
# epoch:498  d_loss:0.1742  g_loss:2.9005
# epoch:499  d_loss:0.1781  g_loss:2.6850
# epoch:500  d_loss:0.1501  g_loss:2.7890
# epoch:501  d_loss:0.2477  g_loss:3.1655
# epoch:502  d_loss:0.3309  g_loss:2.5057
# epoch:503  d_loss:0.2737  g_loss:2.2609
# epoch:504  d_loss:0.2871  g_loss:2.6159
# epoch:505  d_loss:0.1719  g_loss:3.6991
# epoch:506  d_loss:0.2020  g_loss:2.7401
# epoch:507  d_loss:0.1279  g_loss:2.5537
# epoch:508  d_loss:0.1918  g_loss:2.8913
# epoch:509  d_loss:0.1989  g_loss:3.1806
# epoch:510  d_loss:0.2507  g_loss:3.0223
# epoch:511  d_loss:0.3800  g_loss:2.5938
# epoch:512  d_loss:0.2921  g_loss:2.2348
# epoch:513  d_loss:0.3367  g_loss:2.2499
# epoch:514  d_loss:0.2914  g_loss:2.3989
# epoch:515  d_loss:0.2403  g_loss:2.6541
# epoch:516  d_loss:0.2475  g_loss:2.4635
# epoch:517  d_loss:0.3220  g_loss:1.9846
# epoch:518  d_loss:0.3554  g_loss:2.4967
# epoch:519  d_loss:0.4106  g_loss:1.7562
# epoch:520  d_loss:0.1961  g_loss:3.0289
# epoch:521  d_loss:0.3201  g_loss:2.8356
# epoch:522  d_loss:0.4925  g_loss:1.5218
# epoch:523  d_loss:0.3830  g_loss:1.7567
# epoch:524  d_loss:0.3867  g_loss:2.4578
# epoch:525  d_loss:0.2447  g_loss:3.1092
# epoch:526  d_loss:0.2731  g_loss:2.7852
# epoch:527  d_loss:0.4616  g_loss:2.3053
# epoch:528  d_loss:0.3174  g_loss:2.2256
# epoch:529  d_loss:0.2583  g_loss:1.9935
# epoch:530  d_loss:0.1670  g_loss:2.3344
# epoch:531  d_loss:0.2302  g_loss:2.4401
# epoch:532  d_loss:0.2212  g_loss:2.2664
# epoch:533  d_loss:0.1964  g_loss:3.0090
# epoch:534  d_loss:0.2042  g_loss:2.7844
# epoch:535  d_loss:0.2711  g_loss:2.7525
# epoch:536  d_loss:0.2406  g_loss:2.3824
# epoch:537  d_loss:0.2758  g_loss:2.0085
# epoch:538  d_loss:0.2599  g_loss:2.2220
# epoch:539  d_loss:0.1559  g_loss:2.8775
# epoch:540  d_loss:0.1894  g_loss:3.1100
# epoch:541  d_loss:0.2386  g_loss:2.5197
# epoch:542  d_loss:0.2294  g_loss:2.8752
# epoch:543  d_loss:0.2595  g_loss:2.5847
# epoch:544  d_loss:0.2094  g_loss:1.9790
# epoch:545  d_loss:0.3087  g_loss:2.1705
# epoch:546  d_loss:0.1971  g_loss:3.5448
# epoch:547  d_loss:0.1332  g_loss:3.1153
# epoch:548  d_loss:0.1584  g_loss:3.0379
# epoch:549  d_loss:0.1639  g_loss:2.6767
# epoch:550  d_loss:0.2469  g_loss:3.1781
# epoch:551  d_loss:0.2462  g_loss:2.0012
# epoch:552  d_loss:0.1823  g_loss:2.7958
# epoch:553  d_loss:0.2303  g_loss:2.4549
# epoch:554  d_loss:0.1641  g_loss:2.9003
# epoch:555  d_loss:0.2232  g_loss:3.0818
# epoch:556  d_loss:0.2093  g_loss:3.3604
# epoch:557  d_loss:0.1476  g_loss:2.8111
# epoch:558  d_loss:0.2088  g_loss:3.0777
# epoch:559  d_loss:0.1900  g_loss:2.2937
# epoch:560  d_loss:0.1936  g_loss:2.4421
# epoch:561  d_loss:0.1511  g_loss:3.4783
# epoch:562  d_loss:0.1298  g_loss:3.1960
# epoch:563  d_loss:0.2272  g_loss:3.2599
# epoch:564  d_loss:0.1984  g_loss:3.4868
# epoch:565  d_loss:0.1854  g_loss:2.7374
# epoch:566  d_loss:0.1194  g_loss:2.4887
# epoch:567  d_loss:0.1941  g_loss:2.6948
# epoch:568  d_loss:0.1007  g_loss:2.6701
# epoch:569  d_loss:0.1879  g_loss:2.9999
# epoch:570  d_loss:0.1222  g_loss:3.4353
# epoch:571  d_loss:0.2301  g_loss:3.8949
# epoch:572  d_loss:0.2141  g_loss:3.7108
# epoch:573  d_loss:0.2544  g_loss:2.7864
# epoch:574  d_loss:0.2905  g_loss:2.4720
# epoch:575  d_loss:0.2693  g_loss:2.4296
# epoch:576  d_loss:0.1096  g_loss:3.2066
# epoch:577  d_loss:0.1892  g_loss:3.9850
# epoch:578  d_loss:0.1636  g_loss:4.0795
# epoch:579  d_loss:0.1953  g_loss:3.5257
# epoch:580  d_loss:0.2472  g_loss:3.1422
# epoch:581  d_loss:0.2352  g_loss:3.1683
# epoch:582  d_loss:0.2036  g_loss:3.1807
# epoch:583  d_loss:0.2200  g_loss:3.0032
# epoch:584  d_loss:0.4254  g_loss:2.7845
# epoch:585  d_loss:0.1894  g_loss:2.8362
# epoch:586  d_loss:0.1919  g_loss:2.8227
# epoch:587  d_loss:0.2387  g_loss:3.2726
# epoch:588  d_loss:0.2199  g_loss:3.0656
# epoch:589  d_loss:0.2473  g_loss:2.3007
# epoch:590  d_loss:0.1911  g_loss:2.4808
# epoch:591  d_loss:0.1223  g_loss:3.6303
# epoch:592  d_loss:0.1879  g_loss:3.6828
# epoch:593  d_loss:0.2340  g_loss:2.3549
# epoch:594  d_loss:0.2841  g_loss:2.8361
# epoch:595  d_loss:0.1441  g_loss:3.5696
# epoch:596  d_loss:0.1025  g_loss:4.4439
# epoch:597  d_loss:0.1848  g_loss:2.8448
# epoch:598  d_loss:0.2430  g_loss:2.3094
# epoch:599  d_loss:0.2175  g_loss:2.4797
# epoch:600  d_loss:0.2724  g_loss:2.7145
# epoch:601  d_loss:0.1020  g_loss:3.2999
# epoch:602  d_loss:0.2382  g_loss:2.8287
# epoch:603  d_loss:0.2543  g_loss:2.3046
# epoch:604  d_loss:0.2501  g_loss:2.8000
# epoch:605  d_loss:0.2242  g_loss:3.8538
# epoch:606  d_loss:0.2657  g_loss:2.2707
# epoch:607  d_loss:0.3539  g_loss:2.0238
# epoch:608  d_loss:0.1937  g_loss:2.2357
# epoch:609  d_loss:0.1990  g_loss:3.1556
# epoch:610  d_loss:0.2149  g_loss:3.3049
# epoch:611  d_loss:0.3088  g_loss:2.6433
# epoch:612  d_loss:0.1590  g_loss:2.5657
# epoch:613  d_loss:0.1440  g_loss:2.3110
# epoch:614  d_loss:0.1645  g_loss:3.0828
# epoch:615  d_loss:0.1475  g_loss:3.4917
# epoch:616  d_loss:0.3206  g_loss:3.1805
# epoch:617  d_loss:0.1391  g_loss:3.2544
# epoch:618  d_loss:0.1382  g_loss:3.0601
# epoch:619  d_loss:0.0788  g_loss:3.2916
# epoch:620  d_loss:0.0961  g_loss:3.2939
# epoch:621  d_loss:0.1783  g_loss:3.5153
# epoch:622  d_loss:0.1520  g_loss:2.9766
# epoch:623  d_loss:0.1041  g_loss:3.6754
# epoch:624  d_loss:0.2784  g_loss:2.5696
# epoch:625  d_loss:0.2007  g_loss:3.2838
# epoch:626  d_loss:0.1528  g_loss:2.9075
# epoch:627  d_loss:0.1581  g_loss:3.5310
# epoch:628  d_loss:0.0804  g_loss:4.3617
# epoch:629  d_loss:0.1572  g_loss:4.6000
# epoch:630  d_loss:0.1288  g_loss:3.1663
# epoch:631  d_loss:0.1658  g_loss:2.8803
# epoch:632  d_loss:0.1312  g_loss:2.1815
# epoch:633  d_loss:0.1832  g_loss:2.9932
# epoch:634  d_loss:0.1209  g_loss:3.0476
# epoch:635  d_loss:0.2011  g_loss:3.7850
# epoch:636  d_loss:0.1453  g_loss:4.2316
# epoch:637  d_loss:0.1593  g_loss:3.1744
# epoch:638  d_loss:0.3018  g_loss:2.6486
# epoch:639  d_loss:0.3567  g_loss:2.6597
# epoch:640  d_loss:0.1363  g_loss:3.9296
# epoch:641  d_loss:0.2121  g_loss:4.6265
# epoch:642  d_loss:0.5934  g_loss:2.3673
# epoch:643  d_loss:0.1967  g_loss:2.3224
# epoch:644  d_loss:0.2052  g_loss:2.6382
# epoch:645  d_loss:0.2008  g_loss:3.3457
# epoch:646  d_loss:0.1320  g_loss:3.8097
# epoch:647  d_loss:0.3246  g_loss:3.5456
# epoch:648  d_loss:0.2269  g_loss:2.5734
# epoch:649  d_loss:0.2083  g_loss:2.3158
# epoch:650  d_loss:0.2010  g_loss:2.9672
# epoch:651  d_loss:0.0912  g_loss:3.7157
# epoch:652  d_loss:0.1798  g_loss:4.5157
# epoch:653  d_loss:0.3470  g_loss:3.8737
# epoch:654  d_loss:0.2280  g_loss:3.3535
# epoch:655  d_loss:0.1671  g_loss:3.0538
# epoch:656  d_loss:0.1901  g_loss:3.3477
# epoch:657  d_loss:0.2255  g_loss:2.9267
# epoch:658  d_loss:0.1547  g_loss:3.3742
# epoch:659  d_loss:0.2586  g_loss:3.0760
# epoch:660  d_loss:0.1866  g_loss:3.5705
# epoch:661  d_loss:0.1954  g_loss:3.3428
# epoch:662  d_loss:0.3062  g_loss:3.9905
# epoch:663  d_loss:0.1953  g_loss:3.7697
# epoch:664  d_loss:0.1397  g_loss:3.1897
# epoch:665  d_loss:0.2244  g_loss:3.0260
# epoch:666  d_loss:0.1175  g_loss:3.5571
# epoch:667  d_loss:0.2033  g_loss:4.0746
# epoch:668  d_loss:0.1668  g_loss:4.7997
# epoch:669  d_loss:0.1564  g_loss:4.3997
# epoch:670  d_loss:0.2922  g_loss:2.6510
# epoch:671  d_loss:0.1209  g_loss:2.1773
# epoch:672  d_loss:0.1353  g_loss:2.3643
# epoch:673  d_loss:0.1861  g_loss:2.5948
# epoch:674  d_loss:0.1141  g_loss:3.7986
# epoch:675  d_loss:0.1928  g_loss:4.2497
# epoch:676  d_loss:0.1122  g_loss:3.6559
# epoch:677  d_loss:0.0973  g_loss:3.7874
# epoch:678  d_loss:0.1815  g_loss:3.2906
# epoch:679  d_loss:0.0886  g_loss:2.9728
# epoch:680  d_loss:0.1218  g_loss:3.2794
# epoch:681  d_loss:0.1879  g_loss:3.7067
# epoch:682  d_loss:0.2376  g_loss:3.3364
# epoch:683  d_loss:0.1990  g_loss:3.1973
# epoch:684  d_loss:0.3830  g_loss:2.7047
# epoch:685  d_loss:0.1937  g_loss:3.5332
# epoch:686  d_loss:0.4693  g_loss:1.6903
# epoch:687  d_loss:0.6058  g_loss:1.8113
# epoch:688  d_loss:0.3259  g_loss:3.1625
# epoch:689  d_loss:0.5725  g_loss:3.6563
# epoch:690  d_loss:0.3946  g_loss:1.9108
# epoch:691  d_loss:0.4891  g_loss:1.5702
# epoch:692  d_loss:0.5492  g_loss:1.8726
# epoch:693  d_loss:0.2783  g_loss:3.0188
# epoch:694  d_loss:0.4324  g_loss:3.0811
# epoch:695  d_loss:0.3174  g_loss:2.5156
# epoch:696  d_loss:0.1891  g_loss:1.5837
# epoch:697  d_loss:0.2713  g_loss:2.2666
# epoch:698  d_loss:0.1608  g_loss:3.3338
# epoch:699  d_loss:0.0955  g_loss:3.7995
# epoch:700  d_loss:0.1331  g_loss:3.5750
# epoch:701  d_loss:0.1688  g_loss:3.4880
# epoch:702  d_loss:0.1764  g_loss:3.1747
# epoch:703  d_loss:0.2727  g_loss:2.6382
# epoch:704  d_loss:0.2772  g_loss:1.8987
# epoch:705  d_loss:0.1533  g_loss:2.3000
# epoch:706  d_loss:0.1652  g_loss:2.9296
# epoch:707  d_loss:0.2157  g_loss:2.7863
# epoch:708  d_loss:0.2329  g_loss:2.1738
# epoch:709  d_loss:0.1918  g_loss:1.9035
# epoch:710  d_loss:0.2668  g_loss:2.4604
# epoch:711  d_loss:0.2295  g_loss:2.5632
# epoch:712  d_loss:0.1566  g_loss:2.7949
# epoch:713  d_loss:0.3025  g_loss:3.4389
# epoch:714  d_loss:0.2047  g_loss:2.3498
# epoch:715  d_loss:0.2871  g_loss:2.5101
# epoch:716  d_loss:0.1435  g_loss:2.8341
# epoch:717  d_loss:0.2840  g_loss:2.9342
# epoch:718  d_loss:0.2066  g_loss:2.7822
# epoch:719  d_loss:0.1768  g_loss:2.7104
# epoch:720  d_loss:0.2186  g_loss:2.6551
# epoch:721  d_loss:0.1776  g_loss:2.6813
# epoch:722  d_loss:0.2490  g_loss:3.1341
# epoch:723  d_loss:0.2641  g_loss:3.0682
# epoch:724  d_loss:0.3144  g_loss:2.8035
# epoch:725  d_loss:0.5559  g_loss:2.6911
# epoch:726  d_loss:0.8657  g_loss:2.8010
# epoch:727  d_loss:0.5846  g_loss:3.0297
# epoch:728  d_loss:0.5962  g_loss:3.1881
# epoch:729  d_loss:0.6502  g_loss:2.8249
# epoch:730  d_loss:0.6088  g_loss:1.4379
# epoch:731  d_loss:0.4829  g_loss:1.6630
# epoch:732  d_loss:0.4602  g_loss:1.8451
# epoch:733  d_loss:0.3310  g_loss:3.2953
# epoch:734  d_loss:0.3897  g_loss:3.6032
# epoch:735  d_loss:0.4313  g_loss:3.7388
# epoch:736  d_loss:0.3971  g_loss:1.8832
# epoch:737  d_loss:0.3711  g_loss:1.7178
# epoch:738  d_loss:0.2805  g_loss:1.6768
# epoch:739  d_loss:0.4535  g_loss:2.3604
# epoch:740  d_loss:0.1795  g_loss:3.2097
# epoch:741  d_loss:0.3952  g_loss:3.3236
# epoch:742  d_loss:0.5675  g_loss:2.2688
# epoch:743  d_loss:0.4155  g_loss:1.6318
# epoch:744  d_loss:0.4623  g_loss:1.7834
# epoch:745  d_loss:0.5192  g_loss:1.3220
# epoch:746  d_loss:0.4029  g_loss:1.9385
# epoch:747  d_loss:0.4559  g_loss:2.1742
# epoch:748  d_loss:0.5112  g_loss:2.1791
# epoch:749  d_loss:0.7080  g_loss:1.2740
# epoch:750  d_loss:0.6583  g_loss:1.0845
# epoch:751  d_loss:0.3719  g_loss:1.6593
# epoch:752  d_loss:0.5415  g_loss:1.1375
# epoch:753  d_loss:0.5984  g_loss:1.4667
# epoch:754  d_loss:0.5205  g_loss:1.2690
# epoch:755  d_loss:0.5288  g_loss:1.1224
# epoch:756  d_loss:0.4434  g_loss:1.4899
# epoch:757  d_loss:0.5852  g_loss:1.1066
# epoch:758  d_loss:0.4747  g_loss:1.4870
# epoch:759  d_loss:0.5641  g_loss:1.4385
# epoch:760  d_loss:0.4365  g_loss:1.5545
# epoch:761  d_loss:0.4189  g_loss:1.4216
# epoch:762  d_loss:0.3672  g_loss:1.3857
# epoch:763  d_loss:0.6271  g_loss:1.2056
# epoch:764  d_loss:0.5722  g_loss:1.2007
# epoch:765  d_loss:0.3442  g_loss:1.4980
# epoch:766  d_loss:0.4287  g_loss:1.2683
# epoch:767  d_loss:0.4583  g_loss:1.8390
# epoch:768  d_loss:0.4666  g_loss:1.8941
# epoch:769  d_loss:0.4163  g_loss:1.9594
# epoch:770  d_loss:0.4120  g_loss:2.0161
# epoch:771  d_loss:0.2633  g_loss:2.7246
# epoch:772  d_loss:0.6768  g_loss:1.9382
# epoch:773  d_loss:0.3708  g_loss:1.7635
# epoch:774  d_loss:0.5874  g_loss:1.7459
# epoch:775  d_loss:0.6323  g_loss:1.8929
# epoch:776  d_loss:0.5442  g_loss:1.7736
# epoch:777  d_loss:0.6162  g_loss:1.2681
# epoch:778  d_loss:0.5434  g_loss:1.2954
# epoch:779  d_loss:0.7736  g_loss:0.9982
# epoch:780  d_loss:0.7572  g_loss:1.2950
# epoch:781  d_loss:0.6025  g_loss:1.3687
# epoch:782  d_loss:1.0461  g_loss:0.7858
# epoch:783  d_loss:0.7404  g_loss:0.8010
# epoch:784  d_loss:0.9354  g_loss:0.7301
# epoch:785  d_loss:0.6909  g_loss:0.9036
# epoch:786  d_loss:0.8379  g_loss:0.9060
# epoch:787  d_loss:0.6687  g_loss:1.7009
# epoch:788  d_loss:0.5577  g_loss:2.7801
# epoch:789  d_loss:0.6033  g_loss:2.7511
# epoch:790  d_loss:0.3337  g_loss:2.4961
# epoch:791  d_loss:0.3472  g_loss:2.4174
# epoch:792  d_loss:0.4016  g_loss:1.6255
# epoch:793  d_loss:0.6988  g_loss:1.2819
# epoch:794  d_loss:0.8760  g_loss:1.1553
# epoch:795  d_loss:0.6575  g_loss:2.1843
# epoch:796  d_loss:0.8639  g_loss:3.1335
# epoch:797  d_loss:0.8097  g_loss:3.5314
# epoch:798  d_loss:0.5799  g_loss:3.5355
# epoch:799  d_loss:0.6636  g_loss:3.7887
# epoch:800  d_loss:0.4777  g_loss:3.2751
# epoch:801  d_loss:0.8391  g_loss:3.4723
# epoch:802  d_loss:0.6975  g_loss:2.2435
# epoch:803  d_loss:0.6147  g_loss:1.6799
# epoch:804  d_loss:0.8156  g_loss:1.5747
# epoch:805  d_loss:1.3868  g_loss:1.1915
# epoch:806  d_loss:0.9350  g_loss:1.5429
# epoch:807  d_loss:1.4057  g_loss:1.6862
# epoch:808  d_loss:1.1432  g_loss:1.3944
# epoch:809  d_loss:0.7519  g_loss:1.3731
# epoch:810  d_loss:0.5273  g_loss:1.7360
# epoch:811  d_loss:0.5347  g_loss:2.3316
# epoch:812  d_loss:0.3671  g_loss:2.8499
# epoch:813  d_loss:0.5695  g_loss:3.3629
# epoch:814  d_loss:0.2685  g_loss:3.7817
# epoch:815  d_loss:0.5458  g_loss:3.1413
# epoch:816  d_loss:0.4416  g_loss:2.5885
# epoch:817  d_loss:0.6491  g_loss:1.9925
# epoch:818  d_loss:0.8998  g_loss:1.5286
# epoch:819  d_loss:0.6837  g_loss:2.5263
# epoch:820  d_loss:0.7754  g_loss:2.8924
# epoch:821  d_loss:1.2021  g_loss:1.6770
# epoch:822  d_loss:0.8301  g_loss:1.4654
# epoch:823  d_loss:0.5117  g_loss:1.6536
# epoch:824  d_loss:0.2682  g_loss:2.7748
# epoch:825  d_loss:0.1650  g_loss:3.8804
# epoch:826  d_loss:0.4193  g_loss:3.7546
# epoch:827  d_loss:0.2443  g_loss:3.3412
# epoch:828  d_loss:0.2324  g_loss:2.6888
# epoch:829  d_loss:0.2556  g_loss:2.3160
# epoch:830  d_loss:0.2060  g_loss:2.4611
# epoch:831  d_loss:0.3808  g_loss:3.0278
# epoch:832  d_loss:0.4372  g_loss:2.9523
# epoch:833  d_loss:0.4127  g_loss:3.0752
# epoch:834  d_loss:0.4082  g_loss:2.6074
# epoch:835  d_loss:0.5901  g_loss:2.2050
# epoch:836  d_loss:0.5490  g_loss:1.9567
# epoch:837  d_loss:0.6791  g_loss:1.4622
# epoch:838  d_loss:0.7654  g_loss:1.2020
# epoch:839  d_loss:0.8885  g_loss:1.2625
# epoch:840  d_loss:0.5235  g_loss:1.5083
# epoch:841  d_loss:0.6836  g_loss:1.3618
# epoch:842  d_loss:0.8318  g_loss:1.2827
# epoch:843  d_loss:0.6575  g_loss:1.1086
# epoch:844  d_loss:0.4680  g_loss:1.3400
# epoch:845  d_loss:0.4738  g_loss:1.5897
# epoch:846  d_loss:0.2848  g_loss:2.4152
# epoch:847  d_loss:0.1947  g_loss:3.2921
# epoch:848  d_loss:0.2824  g_loss:3.5012
# epoch:849  d_loss:0.1881  g_loss:4.0744
# epoch:850  d_loss:0.1707  g_loss:3.6949
# epoch:851  d_loss:0.2888  g_loss:3.3854
# epoch:852  d_loss:0.3780  g_loss:2.9917
# epoch:853  d_loss:0.2879  g_loss:2.5300
# epoch:854  d_loss:0.2973  g_loss:2.9653
# epoch:855  d_loss:0.2233  g_loss:3.4369
# epoch:856  d_loss:0.2088  g_loss:3.3725
# epoch:857  d_loss:0.3800  g_loss:3.0132
# epoch:858  d_loss:0.6665  g_loss:2.6210
# epoch:859  d_loss:0.3772  g_loss:2.5103
# epoch:860  d_loss:0.4100  g_loss:2.6539
# epoch:861  d_loss:0.4856  g_loss:2.9373
# epoch:862  d_loss:0.3346  g_loss:2.7205
# epoch:863  d_loss:0.3837  g_loss:2.1058
# epoch:864  d_loss:0.2139  g_loss:2.7148
# epoch:865  d_loss:0.2948  g_loss:3.0898
# epoch:866  d_loss:0.3257  g_loss:2.8186
# epoch:867  d_loss:0.3230  g_loss:2.7490
# epoch:868  d_loss:0.3147  g_loss:2.3938
# epoch:869  d_loss:0.5383  g_loss:2.0767
# epoch:870  d_loss:0.3088  g_loss:1.8454
# epoch:871  d_loss:0.2890  g_loss:2.1846
# epoch:872  d_loss:0.2985  g_loss:2.5826
# epoch:873  d_loss:0.4999  g_loss:1.8133
# epoch:874  d_loss:0.3064  g_loss:2.3439
# epoch:875  d_loss:0.4086  g_loss:2.2087
# epoch:876  d_loss:0.6172  g_loss:1.8657
# epoch:877  d_loss:0.4443  g_loss:2.0636
# epoch:878  d_loss:0.4825  g_loss:2.2286
# epoch:879  d_loss:0.6158  g_loss:1.6995
# epoch:880  d_loss:0.5388  g_loss:1.5299
# epoch:881  d_loss:0.5935  g_loss:1.6228
# epoch:882  d_loss:0.5233  g_loss:1.5522
# epoch:883  d_loss:0.6257  g_loss:1.3892
# epoch:884  d_loss:0.7096  g_loss:1.3882
# epoch:885  d_loss:0.4902  g_loss:1.2979
# epoch:886  d_loss:0.5764  g_loss:1.6137
# epoch:887  d_loss:0.5088  g_loss:1.4955
# epoch:888  d_loss:0.4866  g_loss:2.0045
# epoch:889  d_loss:0.3809  g_loss:1.8293
# epoch:890  d_loss:0.4293  g_loss:1.5375
# epoch:891  d_loss:0.3310  g_loss:1.9261
# epoch:892  d_loss:0.3784  g_loss:1.9385
# epoch:893  d_loss:0.4256  g_loss:1.6297
# epoch:894  d_loss:0.2706  g_loss:1.9203
# epoch:895  d_loss:0.2861  g_loss:1.9818
# epoch:896  d_loss:0.2488  g_loss:2.1179
# epoch:897  d_loss:0.2038  g_loss:2.1768
# epoch:898  d_loss:0.2454  g_loss:2.3762
# epoch:899  d_loss:0.1963  g_loss:2.6005
# epoch:900  d_loss:0.1786  g_loss:2.7081
# epoch:901  d_loss:0.1313  g_loss:3.1167
# epoch:902  d_loss:0.1752  g_loss:3.2122
# epoch:903  d_loss:0.2504  g_loss:3.2947
# epoch:904  d_loss:0.1722  g_loss:3.2350
# epoch:905  d_loss:0.1754  g_loss:3.1341
# epoch:906  d_loss:0.1392  g_loss:3.0205
# epoch:907  d_loss:0.1482  g_loss:3.0033
# epoch:908  d_loss:0.2053  g_loss:3.1683
# epoch:909  d_loss:0.2676  g_loss:2.7134
# epoch:910  d_loss:0.3009  g_loss:2.8429
# epoch:911  d_loss:0.1511  g_loss:3.0620
# epoch:912  d_loss:0.3406  g_loss:2.5096
# epoch:913  d_loss:0.3818  g_loss:2.6749
# epoch:914  d_loss:0.3542  g_loss:2.4860
# epoch:915  d_loss:0.3311  g_loss:2.8253
# epoch:916  d_loss:0.2560  g_loss:2.6549
# epoch:917  d_loss:0.5610  g_loss:2.3037
# epoch:918  d_loss:0.3508  g_loss:2.0575
# epoch:919  d_loss:0.4122  g_loss:1.9495
# epoch:920  d_loss:0.4667  g_loss:1.8918
# epoch:921  d_loss:0.4107  g_loss:1.8414
# epoch:922  d_loss:0.3882  g_loss:2.3536
# epoch:923  d_loss:0.4846  g_loss:2.2794
# epoch:924  d_loss:0.3027  g_loss:2.4840
# epoch:925  d_loss:0.4159  g_loss:1.6392
# epoch:926  d_loss:0.3988  g_loss:1.9288
# epoch:927  d_loss:0.3726  g_loss:1.7506
# epoch:928  d_loss:0.4892  g_loss:1.5906
# epoch:929  d_loss:0.3747  g_loss:1.2891
# epoch:930  d_loss:0.4501  g_loss:1.6937
# epoch:931  d_loss:0.3973  g_loss:1.5874
# epoch:932  d_loss:0.2882  g_loss:2.2856
# epoch:933  d_loss:0.3509  g_loss:2.2574
# epoch:934  d_loss:0.4427  g_loss:2.5522
# epoch:935  d_loss:0.3159  g_loss:2.4267
# epoch:936  d_loss:0.4357  g_loss:1.8359
# epoch:937  d_loss:0.3329  g_loss:1.8529
# epoch:938  d_loss:0.3259  g_loss:2.1254
# epoch:939  d_loss:0.2769  g_loss:1.7902
# epoch:940  d_loss:0.4854  g_loss:1.5980
# epoch:941  d_loss:0.2238  g_loss:2.3918
# epoch:942  d_loss:0.2740  g_loss:2.3969
# epoch:943  d_loss:0.2698  g_loss:2.1915
# epoch:944  d_loss:0.2646  g_loss:2.3011
# epoch:945  d_loss:0.2350  g_loss:1.8419
# epoch:946  d_loss:0.3799  g_loss:2.1472
# epoch:947  d_loss:0.4041  g_loss:1.7901
# epoch:948  d_loss:0.3135  g_loss:1.8644
# epoch:949  d_loss:0.3117  g_loss:2.2575
# epoch:950  d_loss:0.3188  g_loss:2.4195
# epoch:951  d_loss:0.4118  g_loss:2.6999
# epoch:952  d_loss:0.3147  g_loss:2.1641
# epoch:953  d_loss:0.3293  g_loss:2.3102
# epoch:954  d_loss:0.2956  g_loss:1.9543
# epoch:955  d_loss:0.2747  g_loss:1.4886
# epoch:956  d_loss:0.3725  g_loss:2.0252
# epoch:957  d_loss:0.2652  g_loss:2.2529
# epoch:958  d_loss:0.3736  g_loss:2.8265
# epoch:959  d_loss:0.4056  g_loss:2.2408
# epoch:960  d_loss:0.3224  g_loss:1.8476
# epoch:961  d_loss:0.4651  g_loss:1.6940
# epoch:962  d_loss:0.4491  g_loss:1.5700
# epoch:963  d_loss:0.4663  g_loss:2.2107
# epoch:964  d_loss:0.4799  g_loss:2.0861
# epoch:965  d_loss:0.5142  g_loss:1.8206
# epoch:966  d_loss:0.4155  g_loss:2.4874
# epoch:967  d_loss:0.4367  g_loss:2.2860
# epoch:968  d_loss:0.3116  g_loss:2.3165
# epoch:969  d_loss:0.4101  g_loss:1.7766
# epoch:970  d_loss:0.4408  g_loss:2.1263
# epoch:971  d_loss:0.5373  g_loss:1.7560
# epoch:972  d_loss:0.4387  g_loss:1.3945
# epoch:973  d_loss:0.5072  g_loss:1.4475
# epoch:974  d_loss:0.5159  g_loss:1.5343
# epoch:975  d_loss:0.4327  g_loss:1.4896
# epoch:976  d_loss:0.5606  g_loss:1.4182
# epoch:977  d_loss:0.4928  g_loss:1.2749
# epoch:978  d_loss:0.4858  g_loss:1.4732
# epoch:979  d_loss:0.4768  g_loss:1.7931
# epoch:980  d_loss:0.3644  g_loss:1.6778
# epoch:981  d_loss:0.4797  g_loss:1.6691
# epoch:982  d_loss:0.4986  g_loss:1.3182
# epoch:983  d_loss:0.5092  g_loss:1.3063
# epoch:984  d_loss:0.5126  g_loss:1.2138
# epoch:985  d_loss:0.4893  g_loss:1.5326
# epoch:986  d_loss:0.4336  g_loss:1.4243
# epoch:987  d_loss:0.4156  g_loss:1.7387
# epoch:988  d_loss:0.4916  g_loss:1.2172
# epoch:989  d_loss:0.4410  g_loss:1.4467
# epoch:990  d_loss:0.4108  g_loss:1.4501
# epoch:991  d_loss:0.3788  g_loss:1.6519
# epoch:992  d_loss:0.3707  g_loss:1.6137
# epoch:993  d_loss:0.4438  g_loss:1.8054
# epoch:994  d_loss:0.4635  g_loss:1.3672
# epoch:995  d_loss:0.4236  g_loss:1.3876
# epoch:996  d_loss:0.4302  g_loss:1.5259
# epoch:997  d_loss:0.3690  g_loss:1.3402
# epoch:998  d_loss:0.4784  g_loss:1.5650
# epoch:999  d_loss:0.3557  g_loss:1.5646
# epoch:1000  d_loss:0.3772  g_loss:1.4308
# epoch:1001  d_loss:0.4267  g_loss:1.8584
# epoch:1002  d_loss:0.3480  g_loss:1.3949
# epoch:1003  d_loss:0.3231  g_loss:2.0820
# epoch:1004  d_loss:0.2574  g_loss:1.9187
# epoch:1005  d_loss:0.3758  g_loss:1.8195
# epoch:1006  d_loss:0.3718  g_loss:2.0229
# epoch:1007  d_loss:0.3168  g_loss:2.1249
# epoch:1008  d_loss:0.3430  g_loss:1.8374
# epoch:1009  d_loss:0.3387  g_loss:1.6963
# epoch:1010  d_loss:0.3444  g_loss:1.9834
# epoch:1011  d_loss:0.3115  g_loss:2.4189
# epoch:1012  d_loss:0.3745  g_loss:2.2676
# epoch:1013  d_loss:0.3125  g_loss:2.2587
# epoch:1014  d_loss:0.3496  g_loss:1.7986
# epoch:1015  d_loss:0.4381  g_loss:1.8801
# epoch:1016  d_loss:0.5222  g_loss:1.7216
# epoch:1017  d_loss:0.3939  g_loss:2.0339
# epoch:1018  d_loss:0.4234  g_loss:2.1484
# epoch:1019  d_loss:0.5000  g_loss:2.0602
# epoch:1020  d_loss:0.5296  g_loss:1.8384
# epoch:1021  d_loss:0.4270  g_loss:2.2311
# epoch:1022  d_loss:0.4967  g_loss:1.6108
# epoch:1023  d_loss:0.6141  g_loss:1.4186
# epoch:1024  d_loss:0.5193  g_loss:1.6480
# epoch:1025  d_loss:0.7009  g_loss:1.4769
# epoch:1026  d_loss:0.7123  g_loss:2.2634
# epoch:1027  d_loss:0.5790  g_loss:2.0559
# epoch:1028  d_loss:0.5322  g_loss:1.4085
# epoch:1029  d_loss:0.6440  g_loss:1.5009
# epoch:1030  d_loss:0.3688  g_loss:1.5149
# epoch:1031  d_loss:0.5049  g_loss:1.7347
# epoch:1032  d_loss:0.5819  g_loss:1.6552
# epoch:1033  d_loss:0.4513  g_loss:1.7963
# epoch:1034  d_loss:0.4035  g_loss:1.7188
# epoch:1035  d_loss:0.5325  g_loss:1.7864
# epoch:1036  d_loss:0.5180  g_loss:1.5794
# epoch:1037  d_loss:0.4720  g_loss:1.8406
# epoch:1038  d_loss:0.4186  g_loss:1.9390
# epoch:1039  d_loss:0.3260  g_loss:2.2916
# epoch:1040  d_loss:0.2226  g_loss:2.3819
# epoch:1041  d_loss:0.3706  g_loss:2.4696
# epoch:1042  d_loss:0.4394  g_loss:1.8548
# epoch:1043  d_loss:0.3799  g_loss:1.9971
# epoch:1044  d_loss:0.3755  g_loss:2.0663
# epoch:1045  d_loss:0.3127  g_loss:2.5317
# epoch:1046  d_loss:0.2858  g_loss:2.4156
# epoch:1047  d_loss:0.4009  g_loss:2.2162
# epoch:1048  d_loss:0.3222  g_loss:2.1926
# epoch:1049  d_loss:0.3312  g_loss:2.3922
# epoch:1050  d_loss:0.3843  g_loss:2.2805
# epoch:1051  d_loss:0.3452  g_loss:2.5043
# epoch:1052  d_loss:0.3124  g_loss:2.5534
# epoch:1053  d_loss:0.2965  g_loss:2.2703
# epoch:1054  d_loss:0.3054  g_loss:2.3614
# epoch:1055  d_loss:0.4482  g_loss:1.9834
# epoch:1056  d_loss:0.3653  g_loss:1.8036
# epoch:1057  d_loss:0.3329  g_loss:2.1043
# epoch:1058  d_loss:0.6066  g_loss:1.7649
# epoch:1059  d_loss:0.3225  g_loss:2.3669
# epoch:1060  d_loss:0.3441  g_loss:2.2601
# epoch:1061  d_loss:0.4451  g_loss:1.9256
# epoch:1062  d_loss:0.4240  g_loss:1.8290
# epoch:1063  d_loss:0.3923  g_loss:2.0157
# epoch:1064  d_loss:0.4666  g_loss:1.8752
# epoch:1065  d_loss:0.3725  g_loss:2.1691
# epoch:1066  d_loss:0.2996  g_loss:2.1120
# epoch:1067  d_loss:0.3264  g_loss:2.4838
# epoch:1068  d_loss:0.4472  g_loss:2.1451
# epoch:1069  d_loss:0.3059  g_loss:2.2600
# epoch:1070  d_loss:0.3782  g_loss:1.8530
# epoch:1071  d_loss:0.4481  g_loss:1.8764
# epoch:1072  d_loss:0.3647  g_loss:2.5026
# epoch:1073  d_loss:0.3728  g_loss:2.7706
# epoch:1074  d_loss:0.3906  g_loss:2.5980
# epoch:1075  d_loss:0.4175  g_loss:2.4695
# epoch:1076  d_loss:0.5176  g_loss:1.4772
# epoch:1077  d_loss:0.4606  g_loss:1.5230
# epoch:1078  d_loss:0.3866  g_loss:2.0436
# epoch:1079  d_loss:0.3918  g_loss:2.1517
# epoch:1080  d_loss:0.5334  g_loss:2.3347
# epoch:1081  d_loss:0.5619  g_loss:2.0898
# epoch:1082  d_loss:0.3703  g_loss:2.2362
# epoch:1083  d_loss:0.3789  g_loss:2.0200
# epoch:1084  d_loss:0.3986  g_loss:1.9916
# epoch:1085  d_loss:0.3080  g_loss:1.9349
# epoch:1086  d_loss:0.3897  g_loss:2.0057
# epoch:1087  d_loss:0.3719  g_loss:2.2028
# epoch:1088  d_loss:0.3805  g_loss:2.0399
# epoch:1089  d_loss:0.4027  g_loss:2.5123
# epoch:1090  d_loss:0.2920  g_loss:2.7625
# epoch:1091  d_loss:0.3851  g_loss:2.5790
# epoch:1092  d_loss:0.3362  g_loss:2.2245
# epoch:1093  d_loss:0.3128  g_loss:2.1177
# epoch:1094  d_loss:0.4554  g_loss:2.1750
# epoch:1095  d_loss:0.4112  g_loss:2.2587
# epoch:1096  d_loss:0.4604  g_loss:2.3488
# epoch:1097  d_loss:0.4043  g_loss:2.5554
# epoch:1098  d_loss:0.3685  g_loss:1.8695
# epoch:1099  d_loss:0.5479  g_loss:2.0583
# epoch:1100  d_loss:0.3984  g_loss:1.9854
# epoch:1101  d_loss:0.3637  g_loss:2.0781
# epoch:1102  d_loss:0.4689  g_loss:2.2533
# epoch:1103  d_loss:0.4072  g_loss:2.4331
# epoch:1104  d_loss:0.3335  g_loss:2.3159
# epoch:1105  d_loss:0.5038  g_loss:2.0407
# epoch:1106  d_loss:0.6106  g_loss:1.6333
# epoch:1107  d_loss:0.4778  g_loss:1.8979
# epoch:1108  d_loss:0.4680  g_loss:1.8309
# epoch:1109  d_loss:0.4807  g_loss:2.0219
# epoch:1110  d_loss:0.3507  g_loss:2.5797
# epoch:1111  d_loss:0.4687  g_loss:2.2799
# epoch:1112  d_loss:0.4978  g_loss:1.9668
# epoch:1113  d_loss:0.5594  g_loss:1.6560
# epoch:1114  d_loss:0.4404  g_loss:1.4216
# epoch:1115  d_loss:0.4979  g_loss:2.0565
# epoch:1116  d_loss:0.5456  g_loss:2.6920
# epoch:1117  d_loss:0.3928  g_loss:2.7328
# epoch:1118  d_loss:0.7591  g_loss:2.5706
# epoch:1119  d_loss:0.5800  g_loss:1.7270
# epoch:1120  d_loss:0.5093  g_loss:1.3481
# epoch:1121  d_loss:0.4715  g_loss:1.4955
# epoch:1122  d_loss:0.3256  g_loss:2.1947
# epoch:1123  d_loss:0.2092  g_loss:2.2241
# epoch:1124  d_loss:0.4702  g_loss:2.6090
# epoch:1125  d_loss:0.4558  g_loss:2.3106
# epoch:1126  d_loss:0.4109  g_loss:1.9411
# epoch:1127  d_loss:0.3835  g_loss:1.7753
# epoch:1128  d_loss:0.3781  g_loss:2.0888
# epoch:1129  d_loss:0.4051  g_loss:2.0796
# epoch:1130  d_loss:0.3828  g_loss:2.1737
# epoch:1131  d_loss:0.5307  g_loss:2.0359
# epoch:1132  d_loss:0.4755  g_loss:1.6761
# epoch:1133  d_loss:0.3983  g_loss:2.0877
# epoch:1134  d_loss:0.4707  g_loss:1.9265
# epoch:1135  d_loss:0.4297  g_loss:1.8201
# epoch:1136  d_loss:0.5184  g_loss:1.7398
# epoch:1137  d_loss:0.5240  g_loss:1.7403
# epoch:1138  d_loss:0.4593  g_loss:1.7615
# epoch:1139  d_loss:0.3565  g_loss:2.3534
# epoch:1140  d_loss:0.4199  g_loss:2.1643
# epoch:1141  d_loss:0.6077  g_loss:2.0403
# epoch:1142  d_loss:0.3421  g_loss:1.9566
# epoch:1143  d_loss:0.5356  g_loss:1.9929
# epoch:1144  d_loss:0.6369  g_loss:1.5039
# epoch:1145  d_loss:0.4527  g_loss:1.8263
# epoch:1146  d_loss:0.4112  g_loss:2.3326
# epoch:1147  d_loss:0.3911  g_loss:2.4461
# epoch:1148  d_loss:0.2874  g_loss:2.1645
# epoch:1149  d_loss:0.3863  g_loss:2.4706
# epoch:1150  d_loss:0.4133  g_loss:2.2239
# epoch:1151  d_loss:0.3134  g_loss:2.2171
# epoch:1152  d_loss:0.3931  g_loss:1.6229
# epoch:1153  d_loss:0.3944  g_loss:2.2124
# epoch:1154  d_loss:0.3914  g_loss:2.2325
# epoch:1155  d_loss:0.4279  g_loss:2.4537
# epoch:1156  d_loss:0.4392  g_loss:2.3356
# epoch:1157  d_loss:0.3321  g_loss:2.4019
# epoch:1158  d_loss:0.2940  g_loss:2.5143
# epoch:1159  d_loss:0.2902  g_loss:2.4592
# epoch:1160  d_loss:0.2797  g_loss:2.0563
# epoch:1161  d_loss:0.3278  g_loss:1.6385
# epoch:1162  d_loss:0.3822  g_loss:1.6194
# epoch:1163  d_loss:0.2345  g_loss:2.4515
# epoch:1164  d_loss:0.3308  g_loss:2.5963
# epoch:1165  d_loss:0.2908  g_loss:2.4750
# epoch:1166  d_loss:0.2816  g_loss:2.5779
# epoch:1167  d_loss:0.4311  g_loss:2.5977
# epoch:1168  d_loss:0.3891  g_loss:2.1441
# epoch:1169  d_loss:0.3501  g_loss:1.7522
# epoch:1170  d_loss:0.4641  g_loss:1.8819
# epoch:1171  d_loss:0.3145  g_loss:2.0187
# epoch:1172  d_loss:0.4887  g_loss:2.0992
# epoch:1173  d_loss:0.3312  g_loss:2.1553
# epoch:1174  d_loss:0.2801  g_loss:2.6931
# epoch:1175  d_loss:0.4022  g_loss:1.8617
# epoch:1176  d_loss:0.3861  g_loss:1.8385
# epoch:1177  d_loss:0.3795  g_loss:2.1682
# epoch:1178  d_loss:0.3342  g_loss:2.0190
# epoch:1179  d_loss:0.3357  g_loss:1.8475
# epoch:1180  d_loss:0.3691  g_loss:2.1509
# epoch:1181  d_loss:0.4260  g_loss:1.9758
# epoch:1182  d_loss:0.3580  g_loss:2.1937
# epoch:1183  d_loss:0.4069  g_loss:2.1826
# epoch:1184  d_loss:0.4066  g_loss:1.9584
# epoch:1185  d_loss:0.3797  g_loss:2.0972
# epoch:1186  d_loss:0.4192  g_loss:2.0919
# epoch:1187  d_loss:0.3143  g_loss:1.6514
# epoch:1188  d_loss:0.3592  g_loss:1.7944
# epoch:1189  d_loss:0.4585  g_loss:1.9834
# epoch:1190  d_loss:0.3428  g_loss:2.2611
# epoch:1191  d_loss:0.3339  g_loss:2.2167
# epoch:1192  d_loss:0.3410  g_loss:2.2835
# epoch:1193  d_loss:0.3079  g_loss:2.3526
# epoch:1194  d_loss:0.5175  g_loss:1.7572
# epoch:1195  d_loss:0.4926  g_loss:1.6368
# epoch:1196  d_loss:0.4040  g_loss:1.6676
# ...
# epoch:1611  d_loss:0.5348  g_loss:1.5366
# epoch:1612  d_loss:0.4264  g_loss:1.5695
# epoch:1613  d_loss:0.5807  g_loss:1.4206
# epoch:1614  d_loss:0.5282  g_loss:1.6788
# epoch:1615  d_loss:0.5839  g_loss:1.4533
# epoch:1616  d_loss:0.7161  g_loss:1.0354
# epoch:1617  d_loss:0.6878  g_loss:1.3471
# epoch:1618  d_loss:0.5723  g_loss:1.3566
# epoch:1619  d_loss:0.4693  g_loss:1.8961
# epoch:1620  d_loss:0.4637  g_loss:1.5536
# epoch:1621  d_loss:0.4348  g_loss:1.7155
# epoch:1622  d_loss:0.4607  g_loss:1.6643
# epoch:1623  d_loss:0.5758  g_loss:1.2971
# epoch:1624  d_loss:0.4994  g_loss:1.2850
# epoch:1625  d_loss:0.4491  g_loss:1.2132
# epoch:1626  d_loss:0.3986  g_loss:1.7853
# epoch:1627  d_loss:0.4942  g_loss:1.8458
# epoch:1628  d_loss:0.5247  g_loss:1.5487
# epoch:1629  d_loss:0.6304  g_loss:1.5947
# epoch:1630  d_loss:0.5038  g_loss:1.4799
# epoch:1631  d_loss:0.4035  g_loss:1.7381
# epoch:1632  d_loss:0.4801  g_loss:1.6981
# epoch:1633  d_loss:0.4040  g_loss:1.9207
# epoch:1634  d_loss:0.4556  g_loss:2.2152
# epoch:1635  d_loss:0.5749  g_loss:1.8824
# epoch:1636  d_loss:0.5318  g_loss:1.5153
# epoch:1637  d_loss:0.5031  g_loss:1.3196
# epoch:1638  d_loss:0.3549  g_loss:1.5538
# epoch:1639  d_loss:0.4181  g_loss:1.7629
# epoch:1640  d_loss:0.4992  g_loss:1.6484
# epoch:1641  d_loss:0.4911  g_loss:1.8077
# epoch:1642  d_loss:0.4696  g_loss:2.0514
# epoch:1643  d_loss:0.3555  g_loss:1.9165
# epoch:1644  d_loss:0.4238  g_loss:2.1016
# epoch:1645  d_loss:0.5149  g_loss:1.8563
# epoch:1646  d_loss:0.4254  g_loss:1.5696
# epoch:1647  d_loss:0.4495  g_loss:1.3960
# epoch:1648  d_loss:0.3009  g_loss:1.7632
# epoch:1649  d_loss:0.6047  g_loss:1.7106
# epoch:1650  d_loss:0.4469  g_loss:1.5393
# epoch:1651  d_loss:0.4544  g_loss:1.6941
# epoch:1652  d_loss:0.3372  g_loss:1.7755
# epoch:1653  d_loss:0.4257  g_loss:1.9500
# epoch:1654  d_loss:0.5190  g_loss:1.6411
# epoch:1655  d_loss:0.3643  g_loss:1.9517
# epoch:1656  d_loss:0.4365  g_loss:1.5743
# epoch:1657  d_loss:0.3109  g_loss:1.9409
# epoch:1658  d_loss:0.3245  g_loss:1.7923
# epoch:1659  d_loss:0.4588  g_loss:1.7773
# epoch:1660  d_loss:0.3161  g_loss:1.8392
# epoch:1661  d_loss:0.4269  g_loss:1.5914
# epoch:1662  d_loss:0.4280  g_loss:1.9809
# epoch:1663  d_loss:0.3625  g_loss:1.6275
# epoch:1664  d_loss:0.4788  g_loss:1.8292
# epoch:1665  d_loss:0.4802  g_loss:1.6378
# epoch:1666  d_loss:0.4963  g_loss:1.5008
# epoch:1667  d_loss:0.3667  g_loss:1.8538
# epoch:1668  d_loss:0.4249  g_loss:1.7428
# epoch:1669  d_loss:0.3981  g_loss:2.3804
# epoch:1670  d_loss:0.4306  g_loss:1.9033
# epoch:1671  d_loss:0.4788  g_loss:2.1683
# epoch:1672  d_loss:0.4945  g_loss:2.0874
# epoch:1673  d_loss:0.4686  g_loss:1.4973
# epoch:1674  d_loss:0.4130  g_loss:1.4047
# epoch:1675  d_loss:0.4286  g_loss:1.4307
# epoch:1676  d_loss:0.4478  g_loss:1.8273
# epoch:1677  d_loss:0.6049  g_loss:2.1470
# epoch:1678  d_loss:0.4665  g_loss:1.7866
# epoch:1679  d_loss:0.5669  g_loss:1.5131
# epoch:1680  d_loss:0.5532  g_loss:1.6086
# epoch:1681  d_loss:0.5382  g_loss:1.5347
# epoch:1682  d_loss:0.6268  g_loss:1.6248
# epoch:1683  d_loss:0.6420  g_loss:1.5890
# epoch:1684  d_loss:0.5350  g_loss:1.5581
# epoch:1685  d_loss:0.6689  g_loss:1.3130
# epoch:1686  d_loss:0.5529  g_loss:1.0198
# epoch:1687  d_loss:0.5442  g_loss:1.1469
# epoch:1688  d_loss:0.6253  g_loss:1.5094
# epoch:1689  d_loss:0.5383  g_loss:1.5267
# epoch:1690  d_loss:0.6777  g_loss:1.6323
# epoch:1691  d_loss:0.6492  g_loss:1.5385
# epoch:1692  d_loss:0.6655  g_loss:1.1286
# epoch:1693  d_loss:0.5762  g_loss:1.3776
# epoch:1694  d_loss:0.4558  g_loss:1.4638
# epoch:1695  d_loss:0.4464  g_loss:1.3731
# epoch:1696  d_loss:0.5365  g_loss:1.0387
# epoch:1697  d_loss:0.5694  g_loss:1.2647
# epoch:1698  d_loss:0.4466  g_loss:1.3108
# epoch:1699  d_loss:0.5491  g_loss:1.3821
# epoch:1700  d_loss:0.4645  g_loss:1.6655
# epoch:1701  d_loss:0.4900  g_loss:1.7751
# epoch:1702  d_loss:0.4982  g_loss:1.4830
# epoch:1703  d_loss:0.4727  g_loss:1.3807
# epoch:1704  d_loss:0.3980  g_loss:1.6583
# epoch:1705  d_loss:0.3554  g_loss:2.0465
# epoch:1706  d_loss:0.4061  g_loss:2.3376
# epoch:1707  d_loss:0.3367  g_loss:2.5732
# epoch:1708  d_loss:0.4004  g_loss:2.0648
# epoch:1709  d_loss:0.3353  g_loss:2.0474
# epoch:1710  d_loss:0.3843  g_loss:1.6651
# epoch:1711  d_loss:0.3849  g_loss:1.6219
# epoch:1712  d_loss:0.3666  g_loss:1.3807
# epoch:1713  d_loss:0.4200  g_loss:1.7993
# epoch:1714  d_loss:0.3350  g_loss:1.9146
# epoch:1715  d_loss:0.3726  g_loss:2.3829
# epoch:1716  d_loss:0.3723  g_loss:2.2455
# epoch:1717  d_loss:0.4115  g_loss:1.7744
# epoch:1718  d_loss:0.3994  g_loss:1.6410
# epoch:1719  d_loss:0.4350  g_loss:1.5436
# epoch:1720  d_loss:0.4005  g_loss:1.9529
# epoch:1721  d_loss:0.4349  g_loss:1.9934
# epoch:1722  d_loss:0.4684  g_loss:2.3217
# epoch:1723  d_loss:0.4295  g_loss:1.9304
# epoch:1724  d_loss:0.3749  g_loss:2.1832
# epoch:1725  d_loss:0.4115  g_loss:1.7580
# epoch:1726  d_loss:0.4016  g_loss:1.7657
# epoch:1727  d_loss:0.4854  g_loss:1.9606
# epoch:1728  d_loss:0.4139  g_loss:1.7979
# epoch:1729  d_loss:0.7419  g_loss:1.5183
# epoch:1730  d_loss:0.4963  g_loss:1.5595
# epoch:1731  d_loss:0.4557  g_loss:1.3926
# epoch:1732  d_loss:0.4303  g_loss:1.5556
# epoch:1733  d_loss:0.5028  g_loss:1.7040
# epoch:1734  d_loss:0.5892  g_loss:1.4969
# epoch:1735  d_loss:0.5574  g_loss:1.6015
# epoch:1736  d_loss:0.4679  g_loss:1.3746
# epoch:1737  d_loss:0.5461  g_loss:1.4585
# epoch:1738  d_loss:0.5448  g_loss:1.3038
# epoch:1739  d_loss:0.5682  g_loss:1.5760
# epoch:1740  d_loss:0.4527  g_loss:1.6117
# epoch:1741  d_loss:0.5854  g_loss:1.5905
# epoch:1742  d_loss:0.5259  g_loss:1.6522
# epoch:1743  d_loss:0.5707  g_loss:1.3332
# epoch:1744  d_loss:0.5940  g_loss:1.4101
# epoch:1745  d_loss:0.4474  g_loss:1.3334
# epoch:1746  d_loss:0.5301  g_loss:1.3206
# epoch:1747  d_loss:0.6144  g_loss:1.3237
# epoch:1748  d_loss:0.6103  g_loss:1.3043
# epoch:1749  d_loss:0.5805  g_loss:1.6937
# epoch:1750  d_loss:0.4161  g_loss:2.0512
# epoch:1751  d_loss:0.4697  g_loss:1.6614
# epoch:1752  d_loss:0.6696  g_loss:1.5585
# epoch:1753  d_loss:0.4748  g_loss:1.4376
# epoch:1754  d_loss:0.6082  g_loss:1.4085
# epoch:1755  d_loss:0.5047  g_loss:1.5586
# epoch:1756  d_loss:0.5084  g_loss:1.8910
# epoch:1757  d_loss:0.7082  g_loss:1.7119
# epoch:1758  d_loss:0.3199  g_loss:1.7566
# epoch:1759  d_loss:0.4829  g_loss:1.8454
# epoch:1760  d_loss:0.4134  g_loss:1.7338
# epoch:1761  d_loss:0.5936  g_loss:1.2575
# epoch:1762  d_loss:0.4936  g_loss:1.3998
# epoch:1763  d_loss:0.3662  g_loss:1.6947
# epoch:1764  d_loss:0.5036  g_loss:1.2906
# epoch:1765  d_loss:0.4499  g_loss:1.6255
# epoch:1766  d_loss:0.4584  g_loss:2.0054
# epoch:1767  d_loss:0.4543  g_loss:1.4739
# epoch:1768  d_loss:0.4726  g_loss:1.4218
# epoch:1769  d_loss:0.4981  g_loss:1.5008
# epoch:1770  d_loss:0.3832  g_loss:1.5440
# epoch:1771  d_loss:0.3900  g_loss:1.9446
# epoch:1772  d_loss:0.4682  g_loss:1.6535
# epoch:1773  d_loss:0.3797  g_loss:1.8723
# epoch:1774  d_loss:0.5940  g_loss:1.4873
# epoch:1775  d_loss:0.3690  g_loss:1.5958
# epoch:1776  d_loss:0.5045  g_loss:1.4750
# epoch:1777  d_loss:0.4286  g_loss:1.5261
# epoch:1778  d_loss:0.4101  g_loss:1.7778
# epoch:1779  d_loss:0.3492  g_loss:1.9905
# epoch:1780  d_loss:0.5703  g_loss:1.9345
# epoch:1781  d_loss:0.4610  g_loss:1.9485
# epoch:1782  d_loss:0.5404  g_loss:1.5490
# epoch:1783  d_loss:0.5415  g_loss:1.2560
# epoch:1784  d_loss:0.5425  g_loss:1.1146
# epoch:1785  d_loss:0.4918  g_loss:1.8778
# epoch:1786  d_loss:0.3570  g_loss:2.1111
# epoch:1787  d_loss:0.4961  g_loss:2.1307
# epoch:1788  d_loss:0.4860  g_loss:1.9121
# epoch:1789  d_loss:0.3660  g_loss:1.5655
# epoch:1790  d_loss:0.4325  g_loss:1.2895
# epoch:1791  d_loss:0.4431  g_loss:1.4724
# epoch:1792  d_loss:0.4616  g_loss:1.6582
# epoch:1793  d_loss:0.4393  g_loss:2.0698
# epoch:1794  d_loss:0.4819  g_loss:2.3226
# epoch:1795  d_loss:0.5684  g_loss:1.5010
# epoch:1796  d_loss:0.4811  g_loss:1.6285
# epoch:1797  d_loss:0.5851  g_loss:1.4582
# epoch:1798  d_loss:0.6152  g_loss:1.2517
# epoch:1799  d_loss:0.4030  g_loss:1.6446
# epoch:1800  d_loss:0.5142  g_loss:1.7492
# epoch:1801  d_loss:0.4721  g_loss:1.8781
# epoch:1802  d_loss:0.6432  g_loss:1.7105
# epoch:1803  d_loss:0.4193  g_loss:1.6326
# epoch:1804  d_loss:0.4802  g_loss:1.3404
# epoch:1805  d_loss:0.5206  g_loss:1.3202
# epoch:1806  d_loss:0.5144  g_loss:1.4923
# epoch:1807  d_loss:0.5839  g_loss:1.4629
# epoch:1808  d_loss:0.7841  g_loss:1.1573
# epoch:1809  d_loss:0.4932  g_loss:1.2985
# epoch:1810  d_loss:0.4413  g_loss:1.7288
# epoch:1811  d_loss:0.5454  g_loss:1.8670
# epoch:1812  d_loss:0.5192  g_loss:1.5867
# epoch:1813  d_loss:0.5578  g_loss:1.3138
# epoch:1814  d_loss:0.5931  g_loss:1.3604
# epoch:1815  d_loss:0.6981  g_loss:1.2883
# epoch:1816  d_loss:0.5268  g_loss:1.3516
# epoch:1817  d_loss:0.5904  g_loss:1.5697
# epoch:1818  d_loss:0.5189  g_loss:1.5459
# epoch:1819  d_loss:0.5258  g_loss:1.4143
# epoch:1820  d_loss:0.4895  g_loss:1.3772
# epoch:1821  d_loss:0.5724  g_loss:1.5015
# epoch:1822  d_loss:0.5585  g_loss:1.1562
# epoch:1823  d_loss:0.3849  g_loss:1.4995
# epoch:1824  d_loss:0.4292  g_loss:1.4854
# epoch:1825  d_loss:0.4925  g_loss:1.7245
# epoch:1826  d_loss:0.5448  g_loss:1.7781
# epoch:1827  d_loss:0.5708  g_loss:1.6471
# epoch:1828  d_loss:0.4816  g_loss:1.4695
# epoch:1829  d_loss:0.4844  g_loss:1.5197
# epoch:1830  d_loss:0.2899  g_loss:1.7294
# epoch:1831  d_loss:0.3982  g_loss:1.7750
# epoch:1832  d_loss:0.3830  g_loss:1.6603
# epoch:1833  d_loss:0.3568  g_loss:1.8128
# epoch:1834  d_loss:0.4764  g_loss:1.5879
# epoch:1835  d_loss:0.4605  g_loss:1.7277
# epoch:1836  d_loss:0.4272  g_loss:1.6728
# epoch:1837  d_loss:0.5487  g_loss:1.5181
# epoch:1838  d_loss:0.4048  g_loss:1.5923
# epoch:1839  d_loss:0.4488  g_loss:1.6111
# epoch:1840  d_loss:0.4178  g_loss:1.5808
# epoch:1841  d_loss:0.3445  g_loss:1.8970
# epoch:1842  d_loss:0.4261  g_loss:1.9342
# epoch:1843  d_loss:0.4691  g_loss:1.6558
# epoch:1844  d_loss:0.4918  g_loss:1.5632
# epoch:1845  d_loss:0.4794  g_loss:1.5909
# epoch:1846  d_loss:0.5021  g_loss:1.8368
# epoch:1847  d_loss:0.3502  g_loss:2.0747
# epoch:1848  d_loss:0.3521  g_loss:1.8952
# epoch:1849  d_loss:0.4356  g_loss:1.9433
# epoch:1850  d_loss:0.4743  g_loss:1.5565
# epoch:1851  d_loss:0.4655  g_loss:1.5892
# epoch:1852  d_loss:0.4793  g_loss:1.5818
# epoch:1853  d_loss:0.4914  g_loss:1.4385
# epoch:1854  d_loss:0.4225  g_loss:1.7773
# epoch:1855  d_loss:0.4504  g_loss:1.7435
# epoch:1856  d_loss:0.4896  g_loss:1.6940
# epoch:1857  d_loss:0.4389  g_loss:1.5445
# epoch:1858  d_loss:0.5015  g_loss:1.6301
# epoch:1859  d_loss:0.4970  g_loss:1.3805
# epoch:1860  d_loss:0.5751  g_loss:1.4022
# epoch:1861  d_loss:0.5214  g_loss:1.2784
# epoch:1862  d_loss:0.4677  g_loss:1.4023
# epoch:1863  d_loss:0.5179  g_loss:1.5734
# epoch:1864  d_loss:0.6179  g_loss:1.4033
# epoch:1865  d_loss:0.5129  g_loss:1.4541
# epoch:1866  d_loss:0.5726  g_loss:1.5714
# epoch:1867  d_loss:0.4309  g_loss:1.5850
# epoch:1868  d_loss:0.4829  g_loss:1.6320
# epoch:1869  d_loss:0.5041  g_loss:1.3556
# epoch:1870  d_loss:0.6580  g_loss:1.2621
# epoch:1871  d_loss:0.5249  g_loss:1.4818
# epoch:1872  d_loss:0.5421  g_loss:1.6047
# epoch:1873  d_loss:0.4453  g_loss:1.5305
# epoch:1874  d_loss:0.4779  g_loss:1.6441
# epoch:1875  d_loss:0.4003  g_loss:1.5405
# epoch:1876  d_loss:0.5353  g_loss:1.7627
# epoch:1877  d_loss:0.4656  g_loss:1.6856
# epoch:1878  d_loss:0.3809  g_loss:1.5689
# epoch:1879  d_loss:0.5015  g_loss:1.6643
# epoch:1880  d_loss:0.4185  g_loss:1.7720
# epoch:1881  d_loss:0.4582  g_loss:1.5959
# epoch:1882  d_loss:0.4543  g_loss:1.5280
# epoch:1883  d_loss:0.5108  g_loss:1.6155
# epoch:1884  d_loss:0.3359  g_loss:2.0139
# epoch:1885  d_loss:0.4738  g_loss:1.6613
# epoch:1886  d_loss:0.4770  g_loss:1.6827
# epoch:1887  d_loss:0.4347  g_loss:1.5296
# epoch:1888  d_loss:0.5446  g_loss:1.8045
# epoch:1889  d_loss:0.3772  g_loss:2.0015
# epoch:1890  d_loss:0.5249  g_loss:1.5952
# epoch:1891  d_loss:0.4260  g_loss:1.5951
# epoch:1892  d_loss:0.4002  g_loss:1.5472
# epoch:1893  d_loss:0.5172  g_loss:1.4655
# epoch:1894  d_loss:0.5641  g_loss:1.5154
# epoch:1895  d_loss:0.4216  g_loss:1.7994
# epoch:1896  d_loss:0.5312  g_loss:1.6777
# epoch:1897  d_loss:0.5721  g_loss:1.7760
# epoch:1898  d_loss:0.5464  g_loss:1.6659
# epoch:1899  d_loss:0.4575  g_loss:1.5196
# epoch:1900  d_loss:0.5885  g_loss:1.4959
# epoch:1901  d_loss:0.5327  g_loss:1.4386
# epoch:1902  d_loss:0.5051  g_loss:1.5807
# epoch:1903  d_loss:0.5676  g_loss:1.5212
# epoch:1904  d_loss:0.5350  g_loss:1.5554
# epoch:1905  d_loss:0.4975  g_loss:1.5403
# epoch:1906  d_loss:0.4863  g_loss:1.9412
# epoch:1907  d_loss:0.4969  g_loss:1.7711
# epoch:1908  d_loss:0.5657  g_loss:1.7835
# epoch:1909  d_loss:0.5137  g_loss:1.6766
# epoch:1910  d_loss:0.5033  g_loss:1.2820
# epoch:1911  d_loss:0.6671  g_loss:1.4410
# epoch:1912  d_loss:0.4569  g_loss:1.4824
# epoch:1913  d_loss:0.4227  g_loss:1.4393
# epoch:1914  d_loss:0.4656  g_loss:1.6749
# epoch:1915  d_loss:0.4027  g_loss:1.6835
# epoch:1916  d_loss:0.4782  g_loss:1.8748
# epoch:1917  d_loss:0.4685  g_loss:1.7130
# epoch:1918  d_loss:0.3725  g_loss:2.1874
# epoch:1919  d_loss:0.5038  g_loss:1.9389
# epoch:1920  d_loss:0.2784  g_loss:1.7366
# epoch:1921  d_loss:0.5246  g_loss:1.6331
# epoch:1922  d_loss:0.5615  g_loss:1.5909
# epoch:1923  d_loss:0.4802  g_loss:1.9064
# epoch:1924  d_loss:0.4830  g_loss:1.6892
# epoch:1925  d_loss:0.5620  g_loss:1.7401
# epoch:1926  d_loss:0.4885  g_loss:1.6248
# epoch:1927  d_loss:0.5177  g_loss:1.4405
# epoch:1928  d_loss:0.6536  g_loss:1.2888
# epoch:1929  d_loss:0.5387  g_loss:1.3208
# epoch:1930  d_loss:0.5230  g_loss:1.5154
# epoch:1931  d_loss:0.6176  g_loss:1.6522
# epoch:1932  d_loss:0.4829  g_loss:1.8809
# epoch:1933  d_loss:0.5326  g_loss:1.3639
# epoch:1934  d_loss:0.5780  g_loss:1.0358
# epoch:1935  d_loss:0.5892  g_loss:1.1137
# epoch:1936  d_loss:0.5684  g_loss:1.2963
# epoch:1937  d_loss:0.6357  g_loss:1.4108
# epoch:1938  d_loss:0.4414  g_loss:1.9116
# epoch:1939  d_loss:0.5535  g_loss:1.4178
# epoch:1940  d_loss:0.5728  g_loss:1.3275
# epoch:1941  d_loss:0.6295  g_loss:1.1230
# epoch:1942  d_loss:0.5678  g_loss:1.5401
# epoch:1943  d_loss:0.4882  g_loss:1.4834
# epoch:1944  d_loss:0.5898  g_loss:1.4872
# epoch:1945  d_loss:0.4885  g_loss:1.2161
# epoch:1946  d_loss:0.5410  g_loss:1.2008
# epoch:1947  d_loss:0.4634  g_loss:1.5962
# epoch:1948  d_loss:0.4209  g_loss:1.8504
# epoch:1949  d_loss:0.4642  g_loss:1.9771
# epoch:1950  d_loss:0.4341  g_loss:2.0897
# epoch:1951  d_loss:0.3930  g_loss:1.5652
# epoch:1952  d_loss:0.5035  g_loss:1.7139
# epoch:1953  d_loss:0.4388  g_loss:1.4794
# epoch:1954  d_loss:0.4171  g_loss:1.6646
# epoch:1955  d_loss:0.3726  g_loss:2.0608
# epoch:1956  d_loss:0.4050  g_loss:2.0521
# epoch:1957  d_loss:0.4027  g_loss:1.6398
# epoch:1958  d_loss:0.5331  g_loss:1.8058
# epoch:1959  d_loss:0.3759  g_loss:1.8747
# epoch:1960  d_loss:0.3733  g_loss:1.7887
# epoch:1961  d_loss:0.4972  g_loss:1.8260
# epoch:1962  d_loss:0.4085  g_loss:1.5716
# epoch:1963  d_loss:0.4069  g_loss:1.5507
# epoch:1964  d_loss:0.4571  g_loss:1.7983
# epoch:1965  d_loss:0.4482  g_loss:1.3893
# epoch:1966  d_loss:0.5499  g_loss:1.5264
# epoch:1967  d_loss:0.3939  g_loss:1.9223
# epoch:1968  d_loss:0.4540  g_loss:2.0007
# epoch:1969  d_loss:0.4770  g_loss:1.6226
# epoch:1970  d_loss:0.4362  g_loss:1.8015
# epoch:1971  d_loss:0.3683  g_loss:1.7453
# epoch:1972  d_loss:0.5758  g_loss:1.5496
# epoch:1973  d_loss:0.4680  g_loss:1.4368
# epoch:1974  d_loss:0.6756  g_loss:1.8309
# epoch:1975  d_loss:0.6938  g_loss:1.7303
# epoch:1976  d_loss:0.5787  g_loss:1.8635
# epoch:1977  d_loss:0.4280  g_loss:2.0027
# epoch:1978  d_loss:0.4457  g_loss:1.5160
# epoch:1979  d_loss:0.6151  g_loss:1.5748
# epoch:1980  d_loss:0.6601  g_loss:1.3580
# epoch:1981  d_loss:0.6911  g_loss:1.5437
# epoch:1982  d_loss:0.6898  g_loss:1.2003
# epoch:1983  d_loss:0.7305  g_loss:0.9912
# epoch:1984  d_loss:0.5526  g_loss:1.4929
# epoch:1985  d_loss:0.5006  g_loss:1.6850
# epoch:1986  d_loss:0.4945  g_loss:1.6956
# epoch:1987  d_loss:0.5569  g_loss:1.5622
# epoch:1988  d_loss:0.5426  g_loss:1.5742
# epoch:1989  d_loss:0.4990  g_loss:1.6547
# epoch:1990  d_loss:0.4918  g_loss:1.5938
# epoch:1991  d_loss:0.4858  g_loss:2.0784
# epoch:1992  d_loss:0.4292  g_loss:1.7729
# epoch:1993  d_loss:0.3953  g_loss:1.7163
# epoch:1994  d_loss:0.5548  g_loss:1.8530
# epoch:1995  d_loss:0.4340  g_loss:1.4543
# epoch:1996  d_loss:0.5426  g_loss:1.5925
# epoch:1997  d_loss:0.4073  g_loss:1.7507
# epoch:1998  d_loss:0.4342  g_loss:1.7478
# epoch:1999  d_loss:0.5733  g_loss:1.6402
# epoch:2000  d_loss:0.4866  g_loss:1.8849
