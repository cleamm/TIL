# %%
# 금요일 파이토치 설명
# 금일 오전 11시까지 이론 설명

# %%
# 원핫인코딩 된 벡터를 인코딩을 통해 차원을 줄임

# 트랜스포머
# 기존의 방법과 달리 RNN의 보정을 위해 사용하는 것이 아닌 attention만으로 구성됨
# attention을 사용하되 LSTM(RNN)을 사용하지 않음.
# 또한 attention만으로 encoding decoding을 진행
# 이에 따라 속도가 훨씬 빨라짐

# %%
# https://jalammar.github.io/illustrated-transformer/
# 트랜스포머 설명
# The animal didn’t cross the street because it was too tired
# 번역: 그 동물은 길을 건너지 않았다 왜냐하면 그것은 너무 피곤했기 때문이다
# 위 문장에서 it은 무엇을 의미할까?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 위 그림과 같이 thinking, machines로 두가지의 단어를 기준으로
# self-attention을 계산하기 위해 벡터 3개를 만들어냄(query, key, value)벡터들...
# thinking의 query 벡터값을 각 단어별 key벡터 값의 내적을 구함
# 내적을 구하여 나온 값을 softmax 계산을 통과하여 합을 1로 만듦

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 위에서 Encoder를 묶은 모델이 bert, Decoder를 묶은 모델이 GPT임
