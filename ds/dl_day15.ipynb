# %% [markdown]
# https://wikidocs.net/22592

# %%
# byte pair encoding(BPE)
# 학습을 시켜도 모르는 단어가 등장할 수 있는데 이 단어를 UNK라고(Unknown Token) 함
# 이와 같은 모르는 단어로 인해 문제를 푸는 것이 까다로운 상황을 OOV(out of vocabulary)라고 함
# 위 문제를 완화해주는 것이 BPE 알고리즘임

# %%
# GPT가 못하는 것
# 수학(합성함수와 같은 요소에 대해서 문제풀이를 잘 못함)
# 단 순차적으로 진행되는 연산에 대해서는 연산을 잘 하지만 비순차적인 연산의 경우는 잘 못함(가장 취약한 분야임)
# openAI에서 연구하는 내용은 
# GPT + Q learning(몬테카를로 기법) + Q*알고리즘(빠른 검색하는 알고리즘) 이런 것을 응용하는 단계

# %%
# 토크나이저
# 센텐스피스도 토크나이저로 쓰임

# 시퀀스 투 시퀀스
# 입력된 시퀀스로부터 다른 도메인의 시퀀스를 출력하는 다양한 분야에서 사용되는 모델

# %% [markdown]
# ![image.png](attachment:image.png)
# https://jalammar.github.io/visualizing-neural-machine-translation-mechanics-of-seq2seq-models-with-attention/
#
# 가운데에 있는 것이 context vector임(=문맥/맥락 정보)

# %%
# 인코더 안은 LSTM(RNN)으로 구성됨

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 그림에서는 크기가 4인 context vector임

# %%
# 입력단어를 벡터로 변환

# 어텐션 매커니즘
# RNN기반의 seq2seq는 두가지 문제가 있음
# 1. 고정된 크기의 벡터에 모든 정보를 압축하려고 하므로 정보손실 발생
# 2. RNN의 고질적 문제인 기울기 손실 문제가 발생(층이 깊어질수록 기울기소실이 발생함)

# 기존 번역은 context vector만 가지고 했었음
# 이를 attention은 인코더에서의 전체 입력 문장을 다시 한번 참고함. 단 특정 단어에 집중하여 참고함

# Attention(Query, Key, Value) = Attention Value
