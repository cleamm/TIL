# %% [markdown]
# # GAN

# %%
# https://ippc.kr/blog/ai%EC%A0%80%EC%9E%91%EA%B6%8C/%EC%83%9D%EC%84%B1%ED%98%95-AI-%EC%A0%80%EC%9E%91%EA%B6%8C-%EB%AC%B8%EC%A0%9C

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# minG는 V(D,G)값을 최소로, maxD는 V(D,G)를 최대로 하는 값을 찾는 것이 목표인 모델임
# log1 = 0, log0 = -np.inf

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# G(z)는 가짜 데이터를 생성하는 것임
# D(x) 는 1이되는 것이 목표(판별자는 진짜를 진짜라고 여겨지도록 학습하기 때문)
# D(G(z)) 는 0이 되도록하는 것이 목표
# D(x)는 0~1사이의 값으로 출력됨
# https://tobigs.gitbook.io/tobigs/deep-learning/computer-vision/gan-generative-adversarial-network
# 위 주소 참고하면 이해하기 쉬울듯
# 참고로 D* 이런식으로 *이 붙기도 하는데 이는 optimal(최적)을 의미함
