# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
t = torch.tensor(10.2, dtype=torch.double)
tensor_1 = torch.arange(0,1000,0.001)

# %%
tensor_1
# Out:
# tensor([0.0000e+00, 1.0000e-03, 2.0000e-03,  ..., 1.0000e+03, 1.0000e+03,
#         1.0000e+03])

# %%
t
# Out:
# tensor(10.2000, dtype=torch.float64)

# %%
t = t.int()
t
# Out:
# tensor(10, dtype=torch.int32)

# %%
empty_t = torch.empty(2,4)
ones_t = torch.ones(2,4)
rand_t = torch.rand(3,3)
randn_t = torch.randn(30)

# %%
empty_t
# Out:
# tensor([[-1.0079e+00,  1.3733e-42,  0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]])

# %%
ones_t
# Out:
# tensor([[1., 1., 1., 1.],
#         [1., 1., 1., 1.]])

# %%
rand_t
# Out:
# tensor([[0.6789, 0.9415, 0.6836],
#         [0.7153, 0.9215, 0.5848],
#         [0.6474, 0.7931, 0.5578]])

# %%
randn_t
# Out:
# tensor([ 0.9504,  0.7974, -0.1858, -0.7573, -1.0448,  0.1064,  0.3312,  0.2701,
#          1.4459,  0.3014, -0.4370,  0.5355, -0.5035, -0.5849, -0.8012,  0.1734,
#         -0.0243,  1.4426,  1.1438, -1.2862,  0.3698,  1.2435, -1.0852,  0.6231,
#         -0.8649,  1.1518,  1.8435,  1.3425,  0.6149, -1.6694])

# %%
torch.mean(rand_t), torch.std(rand_t)
# Out:
# (tensor(0.7249), tensor(0.1359))

# %%
a = torch.ones(2,3)
b = torch.ones(2,3) * 2
c = a + b # 텐서 덧셈
d = torch.mm(a, b.T) # 행렬 곱

# %%
a, b
# Out:
# (tensor([[1., 1., 1.],
#          [1., 1., 1.]]),
#  tensor([[2., 2., 2.],
#          [2., 2., 2.]]))

# %%
c
# Out:
# tensor([[3., 3., 3.],
#         [3., 3., 3.]])

# %%
a, b.T
# Out:
# (tensor([[1., 1., 1.],
#          [1., 1., 1.]]),
#  tensor([[2., 2.],
#          [2., 2.],
#          [2., 2.]]))

# %%
d  
# [[1., 1., 1.],  * [[2., 2.],
#  [1., 1., 1.]]     [2., 2.],
#                    [2., 2.]]
# Out:
# tensor([[6., 6.],
#         [6., 6.]])
